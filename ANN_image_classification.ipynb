# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
# Define constants
IMG_HEIGHT = 255
IMG_WIDTH = 255
batch_size = 32
epochs = 10

# %%
# Data preprocessing
train_data_gen = ImageDataGenerator(rescale=1./255)
train_generator = train_data_gen.flow_from_directory(
    directory='D:/data set/cat-dog/training_set/training_set',
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=batch_size,
    class_mode='binary'
)
# Out:
# Found 8005 images belonging to 2 classes.

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense

# %%
ann = Sequential()

# %%
ann.add(Flatten(input_shape=(IMG_HEIGHT, IMG_WIDTH, 3)))
ann.add(tf.keras.layers.Dense(units=6, activation="relu"))
ann.add(tf.keras.layers.Dense(units=6, activation="relu"))
ann.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# %%
ann.compile(
    optimizer = "Adam",
    loss = "binary_crossentropy",
    metrics = ["accuracy"]
)

# %%
ann.fit(train_generator, batch_size = 32, epochs=100)
# Out:
# Epoch 1/100
# 251/251 [==============================] - 20s 74ms/step - loss: 0.8065 - accuracy: 0.4992
# Epoch 2/100
# 251/251 [==============================] - 18s 70ms/step - loss: 0.6932 - accuracy: 0.4997
# Epoch 3/100
# 251/251 [==============================] - 18s 72ms/step - loss: 0.6932 - accuracy: 0.4969
# Epoch 4/100
# 251/251 [==============================] - 18s 72ms/step - loss: 0.6932 - accuracy: 0.4897
# Epoch 5/100
# 251/251 [==============================] - 18s 71ms/step - loss: 0.6932 - accuracy: 0.4997
# Epoch 6/100
# 251/251 [==============================] - 18s 71ms/step - loss: 0.6932 - accuracy: 0.4956
# Epoch 7/100
# 251/251 [==============================] - 18s 71ms/step - loss: 0.6932 - accuracy: 0.4971
# Epoch 8/100
# 251/251 [==============================] - 17s 70ms/step - loss: 0.6932 - accuracy: 0.4921
# Epoch 9/100
# 251/251 [==============================] - 16s 65ms/step - loss: 0.6932 - accuracy: 0.4989
# Epoch 10/100
# 251/251 [==============================] - 16s 65ms/step - loss: 0.6932 - accuracy: 0.4961
# Epoch 11/100
# 251/251 [==============================] - 16s 63ms/step - loss: 0.6932 - accuracy: 0.4894
# Epoch 12/100
# 251/251 [==============================] - 16s 63ms/step - loss: 0.6932 - accuracy: 0.4922
# Epoch 13/100
# 251/251 [==============================] - 16s 62ms/step - loss: 0.6932 - accuracy: 0.4956
# Epoch 14/100
# 251/251 [==============================] - 15s 62ms/step - loss: 0.6932 - accuracy: 0.4916
# Epoch 15/100
# 251/251 [==============================] - 16s 62ms/step - loss: 0.6932 - accuracy: 0.4952
# Epoch 16/100
# 251/251 [==============================] - 15s 61ms/step - loss: 0.6932 - accuracy: 0.4913
# Epoch 17/100
# 251/251 [==============================] - 16s 62ms/step - loss: 0.6932 - accuracy: 0.4974
# Epoch 18/100
# 251/251 [==============================] - 16s 62ms/step - loss: 0.6932 - accuracy: 0.4931
# Epoch 19/100
# 251/251 [==============================] - 15s 61ms/step - loss: 0.6932 - accuracy: 0.5003
# Epoch 20/100
# 251/251 [==============================] - 15s 62ms/step - loss: 0.6932 - accuracy: 0.4946
# Epoch 21/100
# 251/251 [==============================] - 16s 62ms/step - loss: 0.6932 - accuracy: 0.5003
# Epoch 22/100
# 251/251 [==============================] - 16s 64ms/step - loss: 0.6932 - accuracy: 0.4854
# Epoch 23/100
# 251/251 [==============================] - 16s 63ms/step - loss: 0.6932 - accuracy: 0.4957
# Epoch 24/100
# 251/251 [==============================] - 16s 64ms/step - loss: 0.6932 - accuracy: 0.4983
# Epoch 25/100
# 251/251 [==============================] - 16s 64ms/step - loss: 0.6932 - accuracy: 0.4967
# Epoch 26/100
# 251/251 [==============================] - 16s 64ms/step - loss: 0.6932 - accuracy: 0.4964
# Epoch 27/100
# 251/251 [==============================] - 16s 63ms/step - loss: 0.6932 - accuracy: 0.4951
# Epoch 28/100
# 251/251 [==============================] - 16s 64ms/step - loss: 0.6932 - accuracy: 0.4901
# Epoch 29/100
# 251/251 [==============================] - 16s 63ms/step - loss: 0.6932 - accuracy: 0.4952
# Epoch 30/100
# 251/251 [==============================] - 16s 64ms/step - loss: 0.6932 - accuracy: 0.4932
# Epoch 31/100
# 251/251 [==============================] - 16s 64ms/step - loss: 0.6932 - accuracy: 0.5003
# Epoch 32/100
# 251/251 [==============================] - 16s 64ms/step - loss: 0.6932 - accuracy: 0.4878
# Epoch 33/100
# 251/251 [==============================] - 16s 64ms/step - loss: 0.6932 - accuracy: 0.4961
# Epoch 34/100
# 251/251 [==============================] - 16s 64ms/step - loss: 0.6932 - accuracy: 0.4971
# Epoch 35/100
# 251/251 [==============================] - 16s 62ms/step - loss: 0.6932 - accuracy: 0.5003
# Epoch 36/100
# 251/251 [==============================] - 16s 64ms/step - loss: 0.6932 - accuracy: 0.5016
# Epoch 37/100
# 251/251 [==============================] - 16s 64ms/step - loss: 0.6932 - accuracy: 0.4929
# Epoch 38/100
# 251/251 [==============================] - 16s 65ms/step - loss: 0.6932 - accuracy: 0.4983
# Epoch 39/100
# 251/251 [==============================] - 16s 64ms/step - loss: 0.6932 - accuracy: 0.4958
# Epoch 40/100
# 251/251 [==============================] - 16s 64ms/step - loss: 0.6932 - accuracy: 0.4997
# Epoch 41/100
# 251/251 [==============================] - 16s 64ms/step - loss: 0.6932 - accuracy: 0.4938
# Epoch 42/100
# 251/251 [==============================] - 16s 64ms/step - loss: 0.6932 - accuracy: 0.4948
# Epoch 43/100
# 251/251 [==============================] - 16s 64ms/step - loss: 0.6932 - accuracy: 0.4906
# Epoch 44/100
# 251/251 [==============================] - 16s 64ms/step - loss: 0.6932 - accuracy: 0.4982
# Epoch 45/100
# 251/251 [==============================] - 16s 63ms/step - loss: 0.6932 - accuracy: 0.4908
# Epoch 46/100
# 251/251 [==============================] - 16s 64ms/step - loss: 0.6932 - accuracy: 0.5006
# Epoch 47/100
# 251/251 [==============================] - 16s 64ms/step - loss: 0.6932 - accuracy: 0.4969
# Epoch 48/100
# 251/251 [==============================] - 16s 65ms/step - loss: 0.6932 - accuracy: 0.4973
# Epoch 49/100
# 251/251 [==============================] - 16s 64ms/step - loss: 0.6932 - accuracy: 0.4927
# Epoch 50/100
# 251/251 [==============================] - 16s 65ms/step - loss: 0.6932 - accuracy: 0.4982
# Epoch 51/100
# 251/251 [==============================] - 16s 65ms/step - loss: 0.6932 - accuracy: 0.4888
# Epoch 52/100
# 251/251 [==============================] - 16s 65ms/step - loss: 0.6932 - accuracy: 0.4987
# Epoch 53/100
# 251/251 [==============================] - 16s 65ms/step - loss: 0.6932 - accuracy: 0.4936
# Epoch 54/100
# 251/251 [==============================] - 16s 65ms/step - loss: 0.6932 - accuracy: 0.4931
# Epoch 55/100
# 251/251 [==============================] - 16s 65ms/step - loss: 0.6932 - accuracy: 0.4947
# Epoch 56/100
# 251/251 [==============================] - 16s 66ms/step - loss: 0.6932 - accuracy: 0.4929
# Epoch 57/100
# 251/251 [==============================] - 16s 65ms/step - loss: 0.6932 - accuracy: 0.4989
# Epoch 58/100
# 251/251 [==============================] - 17s 67ms/step - loss: 0.6932 - accuracy: 0.4973
# Epoch 59/100
# 251/251 [==============================] - 17s 66ms/step - loss: 0.6932 - accuracy: 0.4894
# Epoch 60/100
# 251/251 [==============================] - 16s 64ms/step - loss: 0.6932 - accuracy: 0.4991
# Epoch 61/100
# 251/251 [==============================] - 16s 66ms/step - loss: 0.6932 - accuracy: 0.4981
# Epoch 62/100
# 251/251 [==============================] - 16s 64ms/step - loss: 0.6932 - accuracy: 0.4964
# Epoch 63/100
# 251/251 [==============================] - 16s 65ms/step - loss: 0.6932 - accuracy: 0.4992
# Epoch 64/100
# 251/251 [==============================] - 16s 64ms/step - loss: 0.6932 - accuracy: 0.4942
# Epoch 65/100
# 251/251 [==============================] - 17s 66ms/step - loss: 0.6932 - accuracy: 0.4934
# Epoch 66/100
# 251/251 [==============================] - 16s 66ms/step - loss: 0.6932 - accuracy: 0.4963
# Epoch 67/100
# 251/251 [==============================] - 16s 66ms/step - loss: 0.6932 - accuracy: 0.4962
# Epoch 68/100
# 251/251 [==============================] - 17s 66ms/step - loss: 0.6932 - accuracy: 0.5003
# Epoch 69/100
# 251/251 [==============================] - 16s 66ms/step - loss: 0.6932 - accuracy: 0.4979
# Epoch 70/100
# 251/251 [==============================] - 16s 66ms/step - loss: 0.6932 - accuracy: 0.4963
# Epoch 71/100
# 251/251 [==============================] - 16s 66ms/step - loss: 0.6932 - accuracy: 0.4938
# Epoch 72/100
# 251/251 [==============================] - 17s 66ms/step - loss: 0.6932 - accuracy: 0.4861
# Epoch 73/100
# 251/251 [==============================] - 17s 67ms/step - loss: 0.6932 - accuracy: 0.5003
# Epoch 74/100
# 251/251 [==============================] - 16s 66ms/step - loss: 0.6932 - accuracy: 0.4864
# Epoch 75/100
# 251/251 [==============================] - 17s 66ms/step - loss: 0.6932 - accuracy: 0.4843
# Epoch 76/100
# 251/251 [==============================] - 16s 65ms/step - loss: 0.6932 - accuracy: 0.4947
# Epoch 77/100
# 251/251 [==============================] - 16s 63ms/step - loss: 0.6932 - accuracy: 0.4936
# Epoch 78/100
# 251/251 [==============================] - 16s 65ms/step - loss: 0.6932 - accuracy: 0.4968
# Epoch 79/100
# 251/251 [==============================] - 16s 64ms/step - loss: 0.6932 - accuracy: 0.5003
# Epoch 80/100
# 251/251 [==============================] - 16s 65ms/step - loss: 0.6932 - accuracy: 0.4966
# Epoch 81/100
# 251/251 [==============================] - 16s 65ms/step - loss: 0.6932 - accuracy: 0.5009
# Epoch 82/100
# 251/251 [==============================] - 16s 65ms/step - loss: 0.6932 - accuracy: 0.4946
# Epoch 83/100
# 251/251 [==============================] - 16s 65ms/step - loss: 0.6932 - accuracy: 0.4959
# Epoch 84/100
# 251/251 [==============================] - 16s 65ms/step - loss: 0.6932 - accuracy: 0.4858
# Epoch 85/100
# 251/251 [==============================] - 16s 65ms/step - loss: 0.6932 - accuracy: 0.4916
# Epoch 86/100
# 251/251 [==============================] - 16s 65ms/step - loss: 0.6932 - accuracy: 0.4942
# Epoch 87/100
# 251/251 [==============================] - 16s 65ms/step - loss: 0.6932 - accuracy: 0.4906
# Epoch 88/100
# 251/251 [==============================] - 16s 64ms/step - loss: 0.6932 - accuracy: 0.5003
# Epoch 89/100
# 251/251 [==============================] - 16s 65ms/step - loss: 0.6932 - accuracy: 0.4948
# Epoch 90/100
# 251/251 [==============================] - 16s 64ms/step - loss: 0.6932 - accuracy: 0.4983
# Epoch 91/100
# 251/251 [==============================] - 16s 64ms/step - loss: 0.6932 - accuracy: 0.4971
# Epoch 92/100
# 251/251 [==============================] - 16s 65ms/step - loss: 0.6932 - accuracy: 0.4898
# Epoch 93/100
# 251/251 [==============================] - 16s 64ms/step - loss: 0.6932 - accuracy: 0.4963
# Epoch 94/100
# 251/251 [==============================] - 16s 64ms/step - loss: 0.6932 - accuracy: 0.4962
# Epoch 95/100
# 251/251 [==============================] - 16s 64ms/step - loss: 0.6932 - accuracy: 0.4982
# Epoch 96/100
# 251/251 [==============================] - 16s 64ms/step - loss: 0.6932 - accuracy: 0.4997
# Epoch 97/100
# 251/251 [==============================] - 16s 65ms/step - loss: 0.6932 - accuracy: 0.4981
# Epoch 98/100
# 251/251 [==============================] - 16s 65ms/step - loss: 0.6932 - accuracy: 0.4906
# Epoch 99/100
# 251/251 [==============================] - 16s 65ms/step - loss: 0.6932 - accuracy: 0.5002
# Epoch 100/100
# 251/251 [==============================] - 16s 65ms/step - loss: 0.6932 - accuracy: 0.4976

# %%
test_data_gen = ImageDataGenerator(rescale=1./255)
test_generator = test_data_gen.flow_from_directory(
    directory='D:/data set/cat-dog/test_set/test_set',
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=batch_size,
    class_mode='binary',
    shuffle=False
)
# Out:
# Found 2023 images belonging to 2 classes.

# %%
y_pred = ann.predict(test_generator)
y_pred = (y_pred > 0.5)
# Out:
# 64/64 [==============================] - 4s 59ms/step

# %%
from sklearn.metrics import accuracy_score

# %%
y_test_flat = test_generator.classes
y_pred_flat = y_pred.flatten()

accuracy = accuracy_score(y_test_flat, y_pred_flat)

print("Accuracy Score:", accuracy)
# Out:
# Accuracy Score: 0.5002471576866041

# %%
from tensorflow.keras.preprocessing import image
import matplotlib.pyplot as plt
import numpy as np

# %%
def predict_image_class(image_path, model):
    img = image.load_img(image_path, target_size=(255, 255))
    plt.imshow(img)
    plt.axis('off')
    plt.show()

    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)
    img_array /= 255.0  # Normalize the image

    prediction = model.predict(img_array)
    if prediction[0] < 0.5:
        return 'Cat'
    else:
        return 'Dog'

image_path = "D:/data set/cat-dog/test_set/test_set/dogs/dog.4084.jpg"
predicted_class = predict_image_class(image_path, ann)
print("Predicted class:", predicted_class)
# Out:
# 1/1 [==============================] - 0s 58ms/step
# Predicted class: Dog
