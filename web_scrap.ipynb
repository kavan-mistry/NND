# %% [markdown]
# * task 1 : count the active researcher
# * task 2 : display department wise research
# * task 3 : dashboard

# %%
import requests 
from bs4 import BeautifulSoup
URL = "https://vidwan.inflibnet.ac.in/searchc/search"

# %%
r = requests.get(URL) 
soup = BeautifulSoup(r.content, 'html5lib') # If this line causes an error, run 'pip install html5lib' or install html5lib 
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <!--[if IE 8]> <html lang="en" class="ie8"> <![endif]-->
# <!--[if IE 9]> <html lang="en" class="ie9"> <![endif]-->
# <!--[if !IE]><!-->
# <html lang="en">
#  <!--<![endif]-->
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <link href="../../favicon.ico" rel="icon"/>
#   <title>
#    Vidwan Search Expert
#   </title>
#   <!-- Web Fonts -->
#   <link href="https://fonts.googleapis.com/css?family=Open+Sans:400,300,600&amp;subset=cyrillic,latin" rel="stylesheet" type="text/css"/>
#   <!-- CSS Global Compulsory -->
#   <link href="https://vidwan.inflibnet.ac.in/files/assets/plugins/bootstrap/css/bootstrap.min.css" rel="stylesheet"/>
#   <link href="https://vidwan.inflibnet.ac.in/files/assets/css/style.css" rel="stylesheet"/>
#   <!-- CSS Header and Footer -->
#   <link href="https://vidwan.inflibnet.ac.in/files/assets/css/headers/header-default.css" rel="stylesheet"/>
# ...

# %%
h4_elements = soup.find_all('h4', class_='title-price')

# Extract the text from the strong tag inside the h4 tag
names = [h4.strong.text.strip().replace("   ","") for h4 in h4_elements]
names
# Out:
# ['Dr  Jagdish Arora',
#  'Dr  Bhabani Das',
#  'Mr.  Mandar Joshi',
#  'Dr  Krishna Pillai Kaliappan',
#  'Dr  Nand Kishore',
#  'Prof  Irishi N N Namboothiri',
#  'Dr  C P Rao',
#  'Dr.  Anil Prakash',
#  'Dr.  Santanu Kumar Sharma',
#  'Dr.  Devendra K Ojha']

# %%
content = '''

<!DOCTYPE html>
<!--[if IE 8]> <html lang="en" class="ie8"> <![endif]-->  
<!--[if IE 9]> <html lang="en" class="ie9"> <![endif]-->  
<!--[if !IE]><!--> <html lang="en" > <!--<![endif]-->
    <head>
        <meta charset="utf-8">
        <meta http-equiv="X-UA-Compatible" content="IE=edge">
        <link rel="icon" href="../../favicon.ico" />

        <title>Vidwan Search Expert</title>

        <!-- Web Fonts -->
        <link rel='stylesheet' type='text/css' href='https://fonts.googleapis.com/css?family=Open+Sans:400,300,600&amp;subset=cyrillic,latin'>

        <!-- CSS Global Compulsory -->
        <link rel="stylesheet" href="https://vidwan.inflibnet.ac.in/files/assets/plugins/bootstrap/css/bootstrap.min.css">
        <link rel="stylesheet" href="https://vidwan.inflibnet.ac.in/files/assets/css/style.css">

        <!-- CSS Header and Footer -->
        <link rel="stylesheet" href="https://vidwan.inflibnet.ac.in/files/assets/css/headers/header-default.css">
        <link rel="stylesheet" href="https://vidwan.inflibnet.ac.in/files/assets/css/footers/footer-v1.css">

        <!-- CSS Implementing Plugins -->
        <link rel="stylesheet" href="https://vidwan.inflibnet.ac.in/files/assets/plugins/animate.css">
        <link rel="stylesheet" href="https://vidwan.inflibnet.ac.in/files/assets/plugins/line-icons/line-icons.css">
        <link rel="stylesheet" href="https://vidwan.inflibnet.ac.in/files/assets/plugins/font-awesome/css/font-awesome.min.css">

        <!-- CSS Page Style -->
        <link rel="stylesheet" href="https://vidwan.inflibnet.ac.in/files/assets/css/pages/profile.css">
        <link rel="stylesheet" href="https://vidwan.inflibnet.ac.in/files/assets/css/pages/shortcode_timeline2.css">

        <!-- CSS Theme -->    
        <link rel="stylesheet" href="https://vidwan.inflibnet.ac.in/files/assets/css/theme-colors/default.css"  id="style_color">
        <link rel="stylesheet" href="https://vidwan.inflibnet.ac.in/files/assets/css/theme-skins/dark.css">

        <!-- CSS Customization -->
        <link rel="stylesheet" href="https://vidwan.inflibnet.ac.in/files/assets/css/custom.css">

        <!-- CSS Autosearch Search-->
        <link rel="stylesheet" href="https://vidwan.inflibnet.ac.in/files/datatable/jquery-ui.css">

        <!-- CSS Global Compulsory -->
        <link rel="stylesheet" href="https://vidwan.inflibnet.ac.in/files/assets/css/shop.style.css">

        <!-- CSS shop.plugins.css  -->
        <link rel="stylesheet" href="https://vidwan.inflibnet.ac.in/files/assets/css/shop.plugins.css ">


        <!-- CSS Header and Footer -->
        <link rel="stylesheet" href="https://vidwan.inflibnet.ac.in/files/assets/css/headers/header-v5.css">
        <link rel="stylesheet" href="https://vidwan.inflibnet.ac.in/files/assets/css/footers/footer-v4.css">


        <!-- JS Global Compulsory -->           
        <script type="text/javascript" src="https://vidwan.inflibnet.ac.in/files/assets/plugins/jquery/jquery.min.js"></script>
        <script type="text/javascript" src="https://vidwan.inflibnet.ac.in/files/assets/plugins/jquery/jquery-migrate.min.js"></script>
        <script type="text/javascript" src="https://vidwan.inflibnet.ac.in/files/assets/plugins/bootstrap/js/bootstrap.min.js"></script> 

        <!-- JS Implementing Plugins -->
        <script type="text/javascript" src="https://vidwan.inflibnet.ac.in/files/assets/plugins/back-to-top.js"></script>
        <script type="text/javascript" src="https://vidwan.inflibnet.ac.in/files/assets/plugins/smoothScroll.js"></script>
        <script type="text/javascript" src="https://vidwan.inflibnet.ac.in/files/assets/plugins/counter/waypoints.min.js"></script>
        <script type="text/javascript" src="https://vidwan.inflibnet.ac.in/files/assets/plugins/counter/jquery.counterup.min.js"></script> 

        <!-- JS Customization -->
        <script type="text/javascript" src="https://vidwan.inflibnet.ac.in/files/assets/js/custom.js"></script>

        <!-- JS Page Level -->           
        <script type="text/javascript" src="https://vidwan.inflibnet.ac.in/files/assets/js/app.js"></script>
        <script type="text/javascript" src="https://vidwan.inflibnet.ac.in/files/assets/js/plugins/datepicker.js"></script>

        <!-- JS Page Validation --> 
        <script type="text/javascript" src="https://vidwan.inflibnet.ac.in/files/assets/plugins/jquery/jquery.validate.min.js"></script>
        <script type="text/javascript" src="https://vidwan.inflibnet.ac.in/files/assets/plugins/jquery/validation-init.js"></script>

        <!-- Datatable CSS-->
        <link href="https://vidwan.inflibnet.ac.in/files/datatable/css/dataTables.responsive.css" rel="stylesheet" />
        <link href="https://vidwan.inflibnet.ac.in/files/datatable/css/jquery.dataTables.css" rel="stylesheet" />

        <!-- CSS Page Search -->
        <link rel="stylesheet" href="https://vidwan.inflibnet.ac.in/files/assets/css/pages/page_search.css">


        <!-- MYICONS -->
        <link href="https://vidwan.inflibnet.ac.in/files/myIcons/MyIcons/flaticon.css" rel="stylesheet" />



        <style type="text/css">
            .ui-autocomplete span.hl_results {
                //  background-color: #ffffff;
            }

            /* loading - the AJAX indicator */
            .ui-autocomplete-loading {
            }

            /* scroll results */
            .ui-autocomplete {
                max-height: 250px;
                overflow-y: auto;
                /* prevent horizontal scrollbar */
                overflow-x: hidden;
                /* add padding for vertical scrollbar */
                padding-right: 5px;
            }

            #title{
                display:inline-block;
                padding:8px;
                width:60%;
            }

        </style>

        <script src="https://vidwan.inflibnet.ac.in/files/datatable/jquery-ui.js"></script>
        <link rel="stylesheet" href="https://vidwan.inflibnet.ac.in/files/datatable/jquery-ui.css">


        <!-- CSS Custom to Override-->
        <link href="https://vidwan.inflibnet.ac.in/files/datatable/mysearchpage.css" rel="stylesheet" /> 
        <link href="https://vidwan.inflibnet.ac.in/files/datatable/homepage.caz.css" rel="stylesheet" /> 

        <!-- code for google analytics ------------------------------------------------------------>
        <!-- Google tag (gtag.js) -->
<script async src="https://www.googletagmanager.com/gtag/js?id=G-VSJZNFDLQ5"></script>
<script>
  window.dataLayer = window.dataLayer || [];
  function gtag(){dataLayer.push(arguments);}
  gtag('js', new Date());

  gtag('config', 'G-VSJZNFDLQ5');
</script>
        <!-- code for google analytics end ------------------------------------------------------------>
    </head>


    <body>
        <div id="page">
            <div class="wrapper">
                <!--=== Header ===-->    
                <!-- CSS Custom to Override -->
<link href="https://vidwan.inflibnet.ac.in/files/datatable/myheader.css" rel="stylesheet" />  
<!-- MYICONS -->
<link href="https://vidwan.inflibnet.ac.in/files/myicons/MyIcons/flaticon.css" rel="stylesheet" />
<!-- JS Global Compulsory -->           
<script type="text/javascript" src="files/assets/plugins/jquery/jquery.min.js"></script>
<script type="text/javascript" src="files/assets/plugins/jquery/jquery-migrate.min.js"></script>

<!--=== Header ===-->    
<div class="header ">
    <div class="container">
        <div class="row">
            <!-- Logo -->
            <div class="col-md-6">
                <a class="logo" href="https://vidwan.inflibnet.ac.in/">
                    <img src="https://vidwan.inflibnet.ac.in/files/logo1.png" alt="Vidwan Logo">
                </a>
            </div>
            <!-- End Logo -->

            <!-- Topbar -->
			 
            <div class="col-md-6">
                <div class="topbar">
                    <div id="Right_logo" class="Right_logo">
                        <img src="https://vidwan.inflibnet.ac.in/files/mhrd_logo.png" alt="MHRD Logo">
						<p>  <b>An MoE Project</b>  <br>
                            National Mission on Education through ICT  <br>(NME-ICT)
						</p><br>
                    </div>
                </div>
            </div>
			<div class="col-md-1">
                <button type="button" class="navbar-toggle" data-toggle="collapse" data-target=".navbar-responsive-collapse">
                    <span class="sr-only">Toggle navigation</span>
                    <span class="fa fa-bars"></span>
                </button>
            </div>
			<div style="clear:both;"></div>
            <!-- End Topbar -->
          
			<!--<div class="col-md-1">
                <div class="topbar">                 		
                            <a href="https://vidwan.inflibnet.ac.in/registration" class="btn-u" target="_blank" style="padding: 4px 13px;">Are you an expert? Register</a>    
                </div>
            </div>-->

            <!-- Toggle get grouped for better mobile display -->
           

            <!-- End Toggle -->
        </div><!--/end row-->
    </div><!--/end container-->

    <!-- Collect the nav links, forms, and other content for toggling -->
    <div class="collapse navbar-collapse mega-menu navbar-responsive-collapse">
        <div class="container">
            <ul class="nav navbar-nav">
                <a style="margin-top:10px;float:left; margin-right: 5px;" download="" href="https://vidwan.inflibnet.ac.in/vidwan_data_collection_format.xlsx" class="btn btn btn-danger btn-xs"> <i class="fa fa-download"></i> Data Collection Format</a>

                <!-- Home -->
                <li>
                 
                    <a href="https://vidwan.inflibnet.ac.in/" class="dropdown-toggle">
                        Home 
                    </a>
                    
                </li>
                <!-- End Home -->
                 <li class="dropdown">
                        <a href="javascript:void(0);" class="dropdown-toggle" data-toggle="dropdown">About Us</a>
                        <ul class="dropdown-menu">
                            <li><a href="https://vidwan.inflibnet.ac.in/#About_Vidwan">About Vidwan</a></li>
                            <li><a href="https://vidwan.inflibnet.ac.in/whyvidwan">Who Can Join ?</a></li>
                            <li><a href="https://vidwan.inflibnet.ac.in/whyvidwan"> Why Vidwan ?</a></li>
                        </ul>
                  </li>	 
                
                   <li class="dropdown">
                        <a href="javascript:void(0);" class="dropdown-toggle" data-toggle="dropdown">Download</a>
                        <ul class="dropdown-menu">
                            <li><a download="" href="https://vidwan.inflibnet.ac.in/vidwan_poster.pdf"> <i class="fa fa-download"></i>Poster</a></li>
                           <!--  <li><a download="" href="proforma.doc"><i class="fa fa-download"></i>Proforma</a></li> -->
                            <li><a download="" href="https://vidwan.inflibnet.ac.in/vidwan_data_collection_format.xlsx"><i class="fa fa-download"></i>Data Collection Format</a></li>
                        </ul>
                  </li>	 
             
				                         
		<li class="dropdown">
                        <a href="javascript:void(0);" class="dropdown-toggle" data-toggle="dropdown">Login</a>
                        <ul class="dropdown-menu">
                            <li><a href="https://vidwan.inflibnet.ac.in/login"><i class="fa fa-sign-in"></i>Login as Expert</a></li>
                            <li><a href="https://vidwan.inflibnet.ac.in/admin"><i class="fa fa-sign-in"></i>Login as Nodal Officer</a></li>
                            <li><a href="https://vidwan.inflibnet.ac.in/Fagencies"><i class="fa fa-sign-in"></i>Login as Funding Agencies</a></li>
                        </ul>
                  </li>	
                  
		<li class="dropdown">
            <a href="javascript:void(0);" class="dropdown-toggle" data-toggle="dropdown">Registration</a>
                    <ul class="dropdown-menu">
                        <li><a href="https://vidwan.inflibnet.ac.in/registration"><i class="fa fa-user-plus"></i>Register as Expert</a></li>
                        <li><a href="https://vidwan.inflibnet.ac.in/registration_nodal"><i class="fa fa-user-plus"></i>Register as Nodal Officer</a></li>
					</ul>
                </li>
            		   <li>
                    <a href="https://vidwan.inflibnet.ac.in/feedback"  class="dropdown-toggle"> 
                       FeedBack 
                    </a>
                    </li>		
               				
               <li>
                    <i class="search fa fa-search search-btn"></i>
                    <div class="search-open">
                        <div class="input-group animated fadeInDown">
                            <form action="https://vidwan.inflibnet.ac.in/searchc/search" method="post">
                                <div style="width: 100%;" class="input-group">
                                    <select style="width: 30%;height:48px" class="form-control" name="field" id="field">
                                        <option selected="selected" value="all">All</option>
                                        <option value="tname">Expert Name</option>
                                        <option value="torganisation">Organisation</option>
                                        <option value="tdesignation">Designation</option>
                                        <option value="texpertise">Expertise</option>
                                        <option value="thonour_awards">Honour Awards</option>
                                        <option value="torg_type">Oraganisation Type</option>
                                        <option value="twos_sub">Web of science</option>

                                    </select>
                                    <input id="title" type="text" class="form-control" style="width: 70%;height:48px"  placeholder="Search for... ..." name="title" value="">
                                    <span class="input-group-btn">
                                        <button class="btn-u btn-u-lg" type="submit"><i class="fa fa-search"></i></button>
                                    </span>
                                </div>
                            </form>
                        </div>
                    </div>    
                </li>
                

            </ul>
        </div><!--/end container-->
    </div><!--/navbar-collapse-->
</div>
<!--=== End Header ===-->
<script>
$(function () {
    $("input[name='org_type[]'][value='Deemed University']").on('click', function(){
        //alert("click");
        $("input[name='org_type[]'][value='Deemed University-Government']").prop('checked', true);
        $("input[name='org_type[]'][value='Deemed University-Private']").prop('checked', true);
        $("input[name='org_type[]'][value='Deemed University-Government Aided']").prop('checked', true);
        //Then submit form
        $("#myform").submit();
    });
});
</script>	
                <!--=== End Header ===-->
                                <!--=== Start Search Page ===-->    
                <div class="content container">
                    <!--Start Form-->
                    <form action="https://vidwan.inflibnet.ac.in/searchc/search" method="post" id="myform" name="myform">
                        <!--Start row--> 
                        <div class="row">
                            <!--Start container Search Bar-->
                            <div class="container">
                                <div class="col-md-9 col-md-offset-3">
                               <!--  <a href="javascript:void(0)" class="clear_filter text-left" style="color: #4765a0"><i class="fa fa-repeat"></i> Clear All Filters</a> -->
                                    <!--Start Search Bar-->
                                    <div id="errornous" class="search-box-form">
                                        <div class="row">

                                            <div class="col-md-3 col-sm-12 col-xs-12 select-city-container">
                                                <div class="selectize-control single">
                                                    <div class="selectize-input items full has-options has-items">
                                                        <select class="newform" name="field" id="field">
                                                            <option value="all" >All</option>
                                                            <option value="tname" >Expert Name</option>
                                                            <option value="torganisation" selected=selected>Organisation</option>
                                                            <option value="tdesignation" >Designation</option>
                                                            <option value="texpertise" >Expertise</option>
                                                            <option value="thonour_awards" >Honour Awards</option>
                                                            <option value="torg_type" >Organisation Type</option>
                                                            <option value="tstate" >State</option>
                                                            <option value="twos_sub" >Web of Science</option>
                                                        </select>
                                                    </div>

                                                </div>
                                            </div>
                                            <div class="col-md-9 col-sm-12 col-xs-12 select-location-container" id="top-search-box">
                                                <div class="selectize-control form-control form-element single">
                                                    <div class="selectize-input items not-full has-options">
                                                        <input id="title"  type="text" autocomplete="off" name="title" value="pandit deendayal energy university" placeholder="Search Expert" style="width: 342px;">
                                                    </div>
                                                </div>
                                                <div class="top-search">
                                                    <button type="submit" id="search" class="btn btn-lg search-btn " > 
                                                        <span class="fa fa-search">
                                                        </span>
                                                        Search
                                                    </button>

                                                </div>
                                            </div>
                                        </div>
                                        <div id="adv-wrp" class="form-toggle">
                                            <span style="padding:3px 6px;border: 1px solid grey">
                                                <input type="radio" name="opt" value="free" >
                                                <span>Free Search</span>
                                            </span>
                                            <span style="padding:3px 6px;border: 1px solid grey">
                                                <input type="radio" name="opt" value="exact" checked=checked> 
                                                <span>Exact Search</span>
                                            </span>
                                        </div>

                                    </div>
                                    <!--EndSearch Bar-->
                                </div>
                            </div>
                            <!--/End container Search Bar-->

                            <!--Start Filters column-->
                            <div class="col-md-3 filter-by-block md-margin-bottom-60">
                                <!-- Start Your Filters-->
                                <div class="panel-group" id="accordion">
                                    <div class="panel panel-default">

                                        <div class="panel-heading">
                                            <h2 class="panel-title">
                                                <a data-toggle="collapse" data-parent="#accordion-V7" href="#collapseSeven" style="  padding: 0px 0px;">
                                                    <h1>Your Filters<i class="fa fa-angle-down"></i></h1>
                                                </a>
                                            </h2>
                                        </div>

                                        <div id="collapseSeven" class="panel-collapse collapse in">
                                            <div class="panel-body">
                                                <!-- Start checkbox-list-->
                                                <ul class="list-unstyled checkbox-list">
                                                    
                                                </ul>  
                                                <!-- End checkbox-list-->
                                            </div>
                                        </div>

                                    </div>
                                </div>
                                <!--/End Your Filters-->
                                <!--Start Filter By-->
                                <h1>Filter By</h1>
                                <!--Start Facet Search For Expertise-->
                                <div class="panel-group" id="accordion">
                                    <div class="panel panel-default">

                                        <div class="panel-heading">
                                            <h2 class="panel-title">
                                                <a data-toggle="collapse" data-parent="#accordion" href="#collapseOne">
                                                    Expertise
                                                    <i class="fa fa-angle-down"></i>
                                                </a>
                                            </h2>
                                        </div>

                                        <div id="collapseOne" class="panel-collapse collapse in">
                                            <div class="panel-body">

                                                <div class="scrollbar" id="style-4">
                                                    <div class="force-overflow">

                                                        <ul class="list-unstyled checkbox-list">
                                                            <li><label class="checkbox"> <input type="checkbox" name="expertise[]"  value="Electrical and Electronic Engineering"   /><i></i>Electrical and Electronic Engineering<small>(3)</small></label><li><li><label class="checkbox"> <input type="checkbox" name="expertise[]"  value="Chemical Engineering"   /><i></i>Chemical Engineering<small>(2)</small></label><li><li><label class="checkbox"> <input type="checkbox" name="expertise[]"  value="Applied Physics"   /><i></i>Applied Physics<small>(1)</small></label><li><li><label class="checkbox"> <input type="checkbox" name="expertise[]"  value="Astronomy and Astrophysics"   /><i></i>Astronomy and Astrophysics<small>(1)</small></label><li><li><label class="checkbox"> <input type="checkbox" name="expertise[]"  value="Biomedical Engineering"   /><i></i>Biomedical Engineering<small>(1)</small></label><li><li><label class="checkbox"> <input type="checkbox" name="expertise[]"  value="Civil Engineering"   /><i></i>Civil Engineering<small>(1)</small></label><li><li><label class="checkbox"> <input type="checkbox" name="expertise[]"  value="Computer Science Artificial Intelligence"   /><i></i>Computer Science Artificial Intelligence<small>(1)</small></label><li><li><label class="checkbox"> <input type="checkbox" name="expertise[]"  value="Condensed Matter Physics"   /><i></i>Condensed Matter Physics<small>(1)</small></label><li><li><label class="checkbox"> <input type="checkbox" name="expertise[]"  value="Mechanical Engineering"   /><i></i>Mechanical Engineering<small>(1)</small></label><li><li><label class="checkbox"> <input type="checkbox" name="expertise[]"  value="Meteorology and Atmospheric Sciences "   /><i></i>Meteorology and Atmospheric Sciences <small>(1)</small></label><li><li><label class="checkbox"> <input type="checkbox" name="expertise[]"  value="Optics"   /><i></i>Optics<small>(1)</small></label><li><li><label class="checkbox"> <input type="checkbox" name="expertise[]"  value="Paleontology"   /><i></i>Paleontology<small>(1)</small></label><li><li><label class="checkbox"> <input type="checkbox" name="expertise[]"  value="Petroleum Engineering"   /><i></i>Petroleum Engineering<small>(1)</small></label><li> 
                                                        </ul>

                                                    </div>
                                                </div>

                                            </div>
                                        </div>
										 <input type="submit" class="btn btn-u" style="margin-left: 144px;" value="Refine Search" />
                                    </div>
                                </div>
                                <!--/End Facet Search For Expertise-->
                                <!--Start Facet Search For WOS-->
                                <div class="panel-group" id="accordion">
                                    <div class="panel panel-default">

                                        <div class="panel-heading">
                                            <h2 class="panel-title">
                                                <a data-toggle="collapse" data-parent="#accordion-V6" href="#collapseSix">
                                                    Subject Category
                                                    <i class="fa fa-angle-down"></i>
                                                </a>
                                            </h2>
                                        </div>

                                        <div id="collapseSix" class="panel-collapse collapse in">
                                            <div class="panel-body">

                                                <div class="scrollbar" id="style-4">
                                                    <div class="force-overflow">

                                                        <ul class="list-unstyled checkbox-list">
                                                            <li><label class="checkbox"><input type="checkbox" name="wos_sub[]" value="Engineering and Technology"   /><i></i>Engineering and Technology<small>(10)</small></label><li><li><label class="checkbox"><input type="checkbox" name="wos_sub[]" value="Physical Sciences"   /><i></i>Physical Sciences<small>(6)</small></label><li> 
                                                        </ul>   
                                                    </div>
                                                </div>
                                            </div>
                                        </div>
										 <input type="submit" class="btn btn-u" style="margin-left: 144px;" value="Refine Search" />
                                    </div>
                                </div>
                                <!--/End Facet Search For WOS-->
                                <!--Start Facet Search For Organisation Type-->
                                <div class="panel-group" id="accordion">
                                    <div class="panel panel-default">

                                        <div class="panel-heading">
                                            <h2 class="panel-title">
                                                <a data-toggle="collapse" data-parent="#accordion-V3" href="#collapseFour">
                                                    Organisation Type
                                                    <i class="fa fa-angle-down"></i>
                                                </a>
                                            </h2>
                                        </div>

                                        <div id="collapseFour" class="panel-collapse collapse in">
                                            <div class="panel-body">

                                                <div class="scrollbar" id="style-4">
                                                    <div class="force-overflow">

                                                        <ul class="list-unstyled checkbox-list">
                                                            <li><label class="checkbox"> <input type="checkbox" name="org_type[]" value="College"   /><i></i>College<small>(13)</small></label><li><li><label class="checkbox"> <input type="checkbox" name="org_type[]" value="Private University"   /><i></i>Private University<small>(3)</small></label><li> 
                                                        </ul>   
                                                    </div>
                                                </div>
                                            </div>
                                        </div>
										 <input type="submit" class="btn btn-u" style="margin-left: 144px;" value="Refine Search" />
                                    </div>
                                </div>   
                                <!--/End Facet Search For Organisation Type-->
                                <!--Start Facet Search For Designation-->
                                <div class="panel-group" id="accordion">
                                    <div class="panel panel-default">

                                        <div class="panel-heading">
                                            <h2 class="panel-title">
                                                <a data-toggle="collapse" data-parent="#accordion-V2" href="#collapseTwo">
                                                    Designation
                                                    <i class="fa fa-angle-down"></i>
                                                </a>
                                            </h2>
                                        </div>

                                        <div id="collapseTwo" class="panel-collapse collapse in">
                                            <div class="panel-body">

                                                <div class="scrollbar" id="style-4">
                                                    <div class="force-overflow">

                                                        <ul class="list-unstyled checkbox-list">
                                                            <li><label class="checkbox"> <input type="checkbox" name="designation[]"  value="Assistant Professor"   /><i></i>Assistant Professor<small>(6)</small></label><li><li><label class="checkbox"> <input type="checkbox" name="designation[]"  value="Assistant Professor (Grade-I)"   /><i></i>Assistant Professor (Grade-I)<small>(3)</small></label><li><li><label class="checkbox"> <input type="checkbox" name="designation[]"  value="Associate Professor"   /><i></i>Associate Professor<small>(3)</small></label><li><li><label class="checkbox"> <input type="checkbox" name="designation[]"  value="Assistant Professor (Grade-II)"   /><i></i>Assistant Professor (Grade-II)<small>(1)</small></label><li><li><label class="checkbox"> <input type="checkbox" name="designation[]"  value="Assistant Professor (Grade-III)"   /><i></i>Assistant Professor (Grade-III)<small>(1)</small></label><li><li><label class="checkbox"> <input type="checkbox" name="designation[]"  value="Dean"   /><i></i>Dean<small>(1)</small></label><li><li><label class="checkbox"> <input type="checkbox" name="designation[]"  value="Faculty"   /><i></i>Faculty<small>(1)</small></label><li> 
                                                        </ul> 

                                                    </div>
                                                </div>

                                            </div>
                                        </div>
										 <input type="submit" class="btn btn-u" style="margin-left: 144px;" value="Refine Search" />
                                    </div>
                                </div>               
                                <!--/End Facet Search For Designation-->
                                <!--Start Facet Search For Organisation-->
                                <div class="panel-group" id="accordion">
                                    <div class="panel panel-default">

                                        <div class="panel-heading">
                                            <h2 class="panel-title">
                                                <a data-toggle="collapse" data-parent="#accordion-V3" href="#collapseThree">
                                                    Organisation
                                                    <i class="fa fa-angle-down"></i>
                                                </a>
                                            </h2>
                                        </div>

                                        <div id="collapseThree" class="panel-collapse collapse in">
                                            <div class="panel-body">

                                                <div class="scrollbar" id="style-4">
                                                    <div class="force-overflow">

                                                        <ul class="list-unstyled checkbox-list">
                                                            <li><label class="checkbox"> <input type="checkbox" name="organisation[]"  value="Pandit Deendayal Energy University"   /><i></i>Pandit Deendayal Energy University<small>(16)</small></label><li> 
                                                        </ul>   
                                                    </div>
                                                </div>
                                            </div>
                                        </div>
										 <input type="submit" class="btn btn-u" style="margin-left: 144px;" value="Refine Search" />
                                    </div>
                                </div>               
                                <!--/End Facet Search For Organisation-->
                                <!--Start Facet Search For State-->
                                <div class="panel-group" id="accordion">
                                    <div class="panel panel-default">

                                        <div class="panel-heading">
                                            <h2 class="panel-title">
                                                <a data-toggle="collapse" data-parent="#accordion-V5" href="#collapseFive">
                                                    State
                                                    <i class="fa fa-angle-down"></i>
                                                </a>
                                            </h2>
                                        </div>

                                        <div id="collapseFive" class="panel-collapse collapse in">
                                            <div class="panel-body">

                                                <div class="scrollbar" id="style-4">
                                                    <div class="force-overflow">

                                                        <ul class="list-unstyled checkbox-list">
                                                            <li><label class="checkbox"><input type="checkbox" name="state[]"  value="Gujarat"   /><i></i>Gujarat<small>(16)</small></label><li> 
                                                        </ul>   
                                                    </div>
                                                </div>
                                            </div>
                                        </div>
										 <input type="submit" class="btn btn-u" style="margin-left: 144px;" value="Refine Search" />
                                    </div>
                                </div>
                                <!--/End Facet Search For State-->

                                <!--/End Filter By-->
                            </div>
                            <!--/End Filters column-->

                            <!--Start Result Display-->
                            <div class="col-md-9">
                                <div class="filter-results">
                                    

                                        
                                        <!--Start Pagination top-->    
                                        <div class="text-center">
                                            <ul class="pagination">
                                                                                            </ul>
                                        </div>
                                        <!--/End Pagination top-->

                                        <!--Start Header Result Display-->
                                        <div class="row margin-bottom-5 results">
                                            <div class="col-sm-6 result-category">
                                                <span class="resultno">
                                                    No. of Results  pandit deendayal energy university ( 16 )  in 49 ms                                                 </span>
                                            </div>
                                            <div class="col-sm-4">
                                                <ul class="list-inline clear-both">
                                                    <li class="sort-list-btn">
                                                        Sort By :
                                                        <select  class="" name="sortfield" id="sortfield">
                                                            <option value="name">Name</option>
                                                            <option value="designation">Designation</option>
                                                            <option value="user_id">Expert ID</option>
                                                            <option value="organisation">Organisation</option>
                                                        </select>
                                                    </li>
                                                </ul>
                                            </div> 
                                            <div class="col-sm-2">
                                                <ul class="list-inline clear-both">
                                                    <li class="sort-list-btn">
                                                        Show :
                                                        <select  class="" name="limits" id="limits">
                                                            <option value="10">10</option>
                                                            <option value="25">25</option>
                                                            <option value="50">50</option>
                                                            <option value="100">100</option>
                                                        </select>
                                                    </li>
                                                </ul>
                                            </div> 
                                        </div>
                                        <!--End Header Result Display-->

                                        
                                            <!--Start  Display A Result-->
                                            <div class="list-product-description product-description-brd">
                                                <div class="row">
                                                    <div class="col-sm-12 ">

                                                        <!--Start  Display A Image-->
                                                        <div class="col-sm-3 product-description">
                                                                                                                        <a href="https://vidwan.inflibnet.ac.in/profile/207432" >
                                                                                                                                <img class="img-circle center-block img-responsive" src="http://irins.org/assets/profile_images/207432.jpg" />
                                                            </a>
                                                        </div>
                                                        <!--/End  Display A Image-->
                                                        <!--Start  Display A Info-->
                                                        <div class="col-sm-9 product-description">
                                                            <div class="overflow-h">

                                                                <ul class="list-inline add-to-wishlist pull-right">
                                                                    <li>
                                                                        <i class="flaticon-id3"></i>
                                                                        <b>Expert ID : </b>207432                                                                    </li>
                                                                </ul>

                                                                <ul class="list-inline add-to-wishlist ">
                                                                    <li>
                                                                        <h4 class="title-price">
                                                                            <i class="fa fa-user"></i>
                                                                            <strong>
                                                                                Dr                                                                                Bhawanisingh Desai                                                                            </strong>
                                                                        </h4>
                                                                    </li>
                                                                    <li>
                                                                        <span class="title-price">
                                                                            <i class="fa fa-briefcase"></i>
                                                                            Dean                                                                        </span>
                                                                    </li>
                                                                </ul>

                                                                <ul class="list-inline margin-bottom-5">
                                                                    <li>
                                                                        <i class="flaticon-light96"></i>
                                                                        <b>Paleontology</b>
                                                                    </li>
                                                                </ul>
                                                                                                                                    <ul class="list-inline add-to-wishlist margin-bottom-5">
                                                                        <li>
                                                                            <i class="fa fa-cog"></i>
                                                                            Ichnology, Invertebrate Fossils,                                                                         </li>
                                                                    </ul>
                                                                                                
                                                                <ul class="list-inline add-to-wishlist">
                                                                    <li>
                                                                        <i class="glyphicon glyphicon-object-align-bottom"></i>
                                                                        Pandit Deendayal Energy University                                                                    </li>
                                                                    <li>
                                                                        <i class="fa fa-home"></i>
                                                                        Gujarat                                                                    </li>
                                                                </ul>

                                                                <a href="https://vidwan.inflibnet.ac.in/profile/207432" style="color: #FFF;" type="button"target="_blank" class="btn-u btn-u-dark-blue pull-right">View Profile</a>


                                                            </div>    
                                                        </div>
                                                        <!--/End  Display A Info-->
                                                    </div>
                                                </div>
                                            </div>  
                                            <!--/End Display A Result-->
                                            
                                            <!--Start  Display A Result-->
                                            <div class="list-product-description product-description-brd">
                                                <div class="row">
                                                    <div class="col-sm-12 ">

                                                        <!--Start  Display A Image-->
                                                        <div class="col-sm-3 product-description">
                                                                                                                        <a href="https://vidwan.inflibnet.ac.in/profile/231914" >
                                                                                                                                <img class="img-circle center-block img-responsive" src="http://irins.org/assets/profile_images/231914.jpg" />
                                                            </a>
                                                        </div>
                                                        <!--/End  Display A Image-->
                                                        <!--Start  Display A Info-->
                                                        <div class="col-sm-9 product-description">
                                                            <div class="overflow-h">

                                                                <ul class="list-inline add-to-wishlist pull-right">
                                                                    <li>
                                                                        <i class="flaticon-id3"></i>
                                                                        <b>Expert ID : </b>231914                                                                    </li>
                                                                </ul>

                                                                <ul class="list-inline add-to-wishlist ">
                                                                    <li>
                                                                        <h4 class="title-price">
                                                                            <i class="fa fa-user"></i>
                                                                            <strong>
                                                                                Dr                                                                                Santosh Satapathy                                                                            </strong>
                                                                        </h4>
                                                                    </li>
                                                                    <li>
                                                                        <span class="title-price">
                                                                            <i class="fa fa-briefcase"></i>
                                                                            Assistant Professor                                                                        </span>
                                                                    </li>
                                                                </ul>

                                                                <ul class="list-inline margin-bottom-5">
                                                                    <li>
                                                                        <i class="flaticon-light96"></i>
                                                                        <b>Computer Science Artificial Intelligence</b>
                                                                    </li>
                                                                </ul>
                                                                                                                                    <ul class="list-inline add-to-wishlist margin-bottom-5">
                                                                        <li>
                                                                            <i class="fa fa-cog"></i>
                                                                            Brain-Human Interface                                                                        </li>
                                                                    </ul>
                                                                                                
                                                                <ul class="list-inline add-to-wishlist">
                                                                    <li>
                                                                        <i class="glyphicon glyphicon-object-align-bottom"></i>
                                                                        Pandit Deendayal Energy University                                                                    </li>
                                                                    <li>
                                                                        <i class="fa fa-home"></i>
                                                                        Gujarat                                                                    </li>
                                                                </ul>

                                                                <a href="https://vidwan.inflibnet.ac.in/profile/231914" style="color: #FFF;" type="button"target="_blank" class="btn-u btn-u-dark-blue pull-right">View Profile</a>


                                                            </div>    
                                                        </div>
                                                        <!--/End  Display A Info-->
                                                    </div>
                                                </div>
                                            </div>  
                                            <!--/End Display A Result-->
                                            
                                            <!--Start  Display A Result-->
                                            <div class="list-product-description product-description-brd">
                                                <div class="row">
                                                    <div class="col-sm-12 ">

                                                        <!--Start  Display A Image-->
                                                        <div class="col-sm-3 product-description">
                                                                                                                        <a href="https://vidwan.inflibnet.ac.in/profile/353416" >
                                                                                                                                <img class="img-circle center-block img-responsive" src="http://irins.org/assets/profile_images/3534161.jpg" />
                                                            </a>
                                                        </div>
                                                        <!--/End  Display A Image-->
                                                        <!--Start  Display A Info-->
                                                        <div class="col-sm-9 product-description">
                                                            <div class="overflow-h">

                                                                <ul class="list-inline add-to-wishlist pull-right">
                                                                    <li>
                                                                        <i class="flaticon-id3"></i>
                                                                        <b>Expert ID : </b>353416                                                                    </li>
                                                                </ul>

                                                                <ul class="list-inline add-to-wishlist ">
                                                                    <li>
                                                                        <h4 class="title-price">
                                                                            <i class="fa fa-user"></i>
                                                                            <strong>
                                                                                Dr                                                                                Ayyanna  Habal                                                                            </strong>
                                                                        </h4>
                                                                    </li>
                                                                    <li>
                                                                        <span class="title-price">
                                                                            <i class="fa fa-briefcase"></i>
                                                                            Assistant Professor (Grade-II)                                                                        </span>
                                                                    </li>
                                                                </ul>

                                                                <ul class="list-inline margin-bottom-5">
                                                                    <li>
                                                                        <i class="flaticon-light96"></i>
                                                                        <b>Civil Engineering</b>
                                                                    </li>
                                                                </ul>
                                                                                                                                    <ul class="list-inline add-to-wishlist margin-bottom-5">
                                                                        <li>
                                                                            <i class="fa fa-cog"></i>
                                                                            Research Interests:
        Mix design, and Performance of Asphalt Mixes (HMA, WMA, RAP, etc.).
        Moisture Susceptibility of Asphalt Mixes using Novel Approaches (SFE, and BBS method).
        Polymer and Crumb Rubber Modified Binder Characterization using Advanced Tests.
        Pavement Analysis, Design, Evaluation, Preservation and Maintenance
        Chemistry of Asphalt binder and Aggregates.
        Utilization of waste material for construction of stabilized/cementitious layered fle                                                                        </li>
                                                                    </ul>
                                                                                                
                                                                <ul class="list-inline add-to-wishlist">
                                                                    <li>
                                                                        <i class="glyphicon glyphicon-object-align-bottom"></i>
                                                                        Pandit Deendayal Energy University                                                                    </li>
                                                                    <li>
                                                                        <i class="fa fa-home"></i>
                                                                        Gujarat                                                                    </li>
                                                                </ul>

                                                                <a href="https://vidwan.inflibnet.ac.in/profile/353416" style="color: #FFF;" type="button"target="_blank" class="btn-u btn-u-dark-blue pull-right">View Profile</a>


                                                            </div>    
                                                        </div>
                                                        <!--/End  Display A Info-->
                                                    </div>
                                                </div>
                                            </div>  
                                            <!--/End Display A Result-->
                                            
                                            <!--Start  Display A Result-->
                                            <div class="list-product-description product-description-brd">
                                                <div class="row">
                                                    <div class="col-sm-12 ">

                                                        <!--Start  Display A Image-->
                                                        <div class="col-sm-3 product-description">
                                                                                                                        <a href="https://vidwan.inflibnet.ac.in/profile/354041" >
                                                                                                                                <img class="img-circle center-block img-responsive" src="http://irins.org/assets/profile_images/354041.jpg" />
                                                            </a>
                                                        </div>
                                                        <!--/End  Display A Image-->
                                                        <!--Start  Display A Info-->
                                                        <div class="col-sm-9 product-description">
                                                            <div class="overflow-h">

                                                                <ul class="list-inline add-to-wishlist pull-right">
                                                                    <li>
                                                                        <i class="flaticon-id3"></i>
                                                                        <b>Expert ID : </b>354041                                                                    </li>
                                                                </ul>

                                                                <ul class="list-inline add-to-wishlist ">
                                                                    <li>
                                                                        <h4 class="title-price">
                                                                            <i class="fa fa-user"></i>
                                                                            <strong>
                                                                                Dr                                                                                Mohendra Roy                                                                            </strong>
                                                                        </h4>
                                                                    </li>
                                                                    <li>
                                                                        <span class="title-price">
                                                                            <i class="fa fa-briefcase"></i>
                                                                            Assistant Professor                                                                        </span>
                                                                    </li>
                                                                </ul>

                                                                <ul class="list-inline margin-bottom-5">
                                                                    <li>
                                                                        <i class="flaticon-light96"></i>
                                                                        <b>Biomedical Engineering</b>
                                                                    </li>
                                                                </ul>
                                                                                                                                    <ul class="list-inline add-to-wishlist margin-bottom-5">
                                                                        <li>
                                                                            <i class="fa fa-cog"></i>
                                                                            Dr. Mohendra Roy is an assistant professor at the School of Technology, Pandit Deendayal Energy University (PDEU), Gandhinagar. He was a postDoctoral Fellow at Delta-NTU Corporate Lab of Nanyang Technological University (NTU) Singapore from the year 2017 to 2019.  He received his Ph.D. in Electronics and Information Engineering from Korea University, South Korea in the year 2016. He did his master's in Bio-Electronics as well as physics from Tezpur Central University, India in the year 2008 and                                                                         </li>
                                                                    </ul>
                                                                                                
                                                                <ul class="list-inline add-to-wishlist">
                                                                    <li>
                                                                        <i class="glyphicon glyphicon-object-align-bottom"></i>
                                                                        Pandit Deendayal Energy University                                                                    </li>
                                                                    <li>
                                                                        <i class="fa fa-home"></i>
                                                                        Gujarat                                                                    </li>
                                                                </ul>

                                                                <a href="https://vidwan.inflibnet.ac.in/profile/354041" style="color: #FFF;" type="button"target="_blank" class="btn-u btn-u-dark-blue pull-right">View Profile</a>


                                                            </div>    
                                                        </div>
                                                        <!--/End  Display A Info-->
                                                    </div>
                                                </div>
                                            </div>  
                                            <!--/End Display A Result-->
                                            
                                            <!--Start  Display A Result-->
                                            <div class="list-product-description product-description-brd">
                                                <div class="row">
                                                    <div class="col-sm-12 ">

                                                        <!--Start  Display A Image-->
                                                        <div class="col-sm-3 product-description">
                                                                                                                        <a href="https://vidwan.inflibnet.ac.in/profile/419526" >
                                                                                                                                <img class="img-circle center-block img-responsive" src="http://irins.org/assets/profile_images/419526.JPG" />
                                                            </a>
                                                        </div>
                                                        <!--/End  Display A Image-->
                                                        <!--Start  Display A Info-->
                                                        <div class="col-sm-9 product-description">
                                                            <div class="overflow-h">

                                                                <ul class="list-inline add-to-wishlist pull-right">
                                                                    <li>
                                                                        <i class="flaticon-id3"></i>
                                                                        <b>Expert ID : </b>419526                                                                    </li>
                                                                </ul>

                                                                <ul class="list-inline add-to-wishlist ">
                                                                    <li>
                                                                        <h4 class="title-price">
                                                                            <i class="fa fa-user"></i>
                                                                            <strong>
                                                                                Dr                                                                                Ravi Tejasvi                                                                            </strong>
                                                                        </h4>
                                                                    </li>
                                                                    <li>
                                                                        <span class="title-price">
                                                                            <i class="fa fa-briefcase"></i>
                                                                            Assistant Professor                                                                        </span>
                                                                    </li>
                                                                </ul>

                                                                <ul class="list-inline margin-bottom-5">
                                                                    <li>
                                                                        <i class="flaticon-light96"></i>
                                                                        <b>Chemical Engineering</b>
                                                                    </li>
                                                                </ul>
                                                                                                                                    <ul class="list-inline add-to-wishlist margin-bottom-5">
                                                                        <li>
                                                                            <i class="fa fa-cog"></i>
                                                                            Green Hydrogen Generation, Hydrogen Purification, Process Equipment Design                                                                        </li>
                                                                    </ul>
                                                                                                
                                                                <ul class="list-inline add-to-wishlist">
                                                                    <li>
                                                                        <i class="glyphicon glyphicon-object-align-bottom"></i>
                                                                        Pandit Deendayal Energy University                                                                    </li>
                                                                    <li>
                                                                        <i class="fa fa-home"></i>
                                                                        Gujarat                                                                    </li>
                                                                </ul>

                                                                <a href="https://vidwan.inflibnet.ac.in/profile/419526" style="color: #FFF;" type="button"target="_blank" class="btn-u btn-u-dark-blue pull-right">View Profile</a>


                                                            </div>    
                                                        </div>
                                                        <!--/End  Display A Info-->
                                                    </div>
                                                </div>
                                            </div>  
                                            <!--/End Display A Result-->
                                            
                                            <!--Start  Display A Result-->
                                            <div class="list-product-description product-description-brd">
                                                <div class="row">
                                                    <div class="col-sm-12 ">

                                                        <!--Start  Display A Image-->
                                                        <div class="col-sm-3 product-description">
                                                                                                                        <a href="https://vidwan.inflibnet.ac.in/profile/419549" >
                                                                                                                                <img class="img-circle center-block img-responsive" src="http://irins.org/assets/profile_images/men.png" />
                                                            </a>
                                                        </div>
                                                        <!--/End  Display A Image-->
                                                        <!--Start  Display A Info-->
                                                        <div class="col-sm-9 product-description">
                                                            <div class="overflow-h">

                                                                <ul class="list-inline add-to-wishlist pull-right">
                                                                    <li>
                                                                        <i class="flaticon-id3"></i>
                                                                        <b>Expert ID : </b>419549                                                                    </li>
                                                                </ul>

                                                                <ul class="list-inline add-to-wishlist ">
                                                                    <li>
                                                                        <h4 class="title-price">
                                                                            <i class="fa fa-user"></i>
                                                                            <strong>
                                                                                Dr                                                                                Abhishek Kumar Gupta                                                                            </strong>
                                                                        </h4>
                                                                    </li>
                                                                    <li>
                                                                        <span class="title-price">
                                                                            <i class="fa fa-briefcase"></i>
                                                                            Assistant Professor (Grade-I)                                                                        </span>
                                                                    </li>
                                                                </ul>

                                                                <ul class="list-inline margin-bottom-5">
                                                                    <li>
                                                                        <i class="flaticon-light96"></i>
                                                                        <b>Chemical Engineering</b>
                                                                    </li>
                                                                </ul>
                                                                                                                                    <ul class="list-inline add-to-wishlist margin-bottom-5">
                                                                        <li>
                                                                            <i class="fa fa-cog"></i>
                                                                            Molecular Simulations, Statistical Mechanics, Enhanced Sampling Methods, Classical Molecular Dynamics Simulations                                                                        </li>
                                                                    </ul>
                                                                                                
                                                                <ul class="list-inline add-to-wishlist">
                                                                    <li>
                                                                        <i class="glyphicon glyphicon-object-align-bottom"></i>
                                                                        Pandit Deendayal Energy University                                                                    </li>
                                                                    <li>
                                                                        <i class="fa fa-home"></i>
                                                                        Gujarat                                                                    </li>
                                                                </ul>

                                                                <a href="https://vidwan.inflibnet.ac.in/profile/419549" style="color: #FFF;" type="button"target="_blank" class="btn-u btn-u-dark-blue pull-right">View Profile</a>


                                                            </div>    
                                                        </div>
                                                        <!--/End  Display A Info-->
                                                    </div>
                                                </div>
                                            </div>  
                                            <!--/End Display A Result-->
                                            
                                            <!--Start  Display A Result-->
                                            <div class="list-product-description product-description-brd">
                                                <div class="row">
                                                    <div class="col-sm-12 ">

                                                        <!--Start  Display A Image-->
                                                        <div class="col-sm-3 product-description">
                                                                                                                        <a href="https://vidwan.inflibnet.ac.in/profile/419564" >
                                                                                                                                <img class="img-circle center-block img-responsive" src="http://irins.org/assets/profile_images/419564.jpeg" />
                                                            </a>
                                                        </div>
                                                        <!--/End  Display A Image-->
                                                        <!--Start  Display A Info-->
                                                        <div class="col-sm-9 product-description">
                                                            <div class="overflow-h">

                                                                <ul class="list-inline add-to-wishlist pull-right">
                                                                    <li>
                                                                        <i class="flaticon-id3"></i>
                                                                        <b>Expert ID : </b>419564                                                                    </li>
                                                                </ul>

                                                                <ul class="list-inline add-to-wishlist ">
                                                                    <li>
                                                                        <h4 class="title-price">
                                                                            <i class="fa fa-user"></i>
                                                                            <strong>
                                                                                Dr                                                                                Rohit Srivastava                                                                            </strong>
                                                                        </h4>
                                                                    </li>
                                                                    <li>
                                                                        <span class="title-price">
                                                                            <i class="fa fa-briefcase"></i>
                                                                            Associate Professor                                                                        </span>
                                                                    </li>
                                                                </ul>

                                                                <ul class="list-inline margin-bottom-5">
                                                                    <li>
                                                                        <i class="flaticon-light96"></i>
                                                                        <b>Meteorology and Atmospheric Sciences </b>
                                                                    </li>
                                                                </ul>
                                                                                                                                    <ul class="list-inline add-to-wishlist margin-bottom-5">
                                                                        <li>
                                                                            <i class="fa fa-cog"></i>
                                                                            Research areas of interest are Global warming, Climate change, Hydrological cycle, Cloud microphysics, Isotope geochemistry, Atmospheric modelling, Computational physics & Sustainable development                                                                        </li>
                                                                    </ul>
                                                                                                
                                                                <ul class="list-inline add-to-wishlist">
                                                                    <li>
                                                                        <i class="glyphicon glyphicon-object-align-bottom"></i>
                                                                        Pandit Deendayal Energy University                                                                    </li>
                                                                    <li>
                                                                        <i class="fa fa-home"></i>
                                                                        Gujarat                                                                    </li>
                                                                </ul>

                                                                <a href="https://vidwan.inflibnet.ac.in/profile/419564" style="color: #FFF;" type="button"target="_blank" class="btn-u btn-u-dark-blue pull-right">View Profile</a>


                                                            </div>    
                                                        </div>
                                                        <!--/End  Display A Info-->
                                                    </div>
                                                </div>
                                            </div>  
                                            <!--/End Display A Result-->
                                            
                                            <!--Start  Display A Result-->
                                            <div class="list-product-description product-description-brd">
                                                <div class="row">
                                                    <div class="col-sm-12 ">

                                                        <!--Start  Display A Image-->
                                                        <div class="col-sm-3 product-description">
                                                                                                                        <a href="https://vidwan.inflibnet.ac.in/profile/419601" >
                                                                                                                                <img class="img-circle center-block img-responsive" src="http://irins.org/assets/profile_images/men.png" />
                                                            </a>
                                                        </div>
                                                        <!--/End  Display A Image-->
                                                        <!--Start  Display A Info-->
                                                        <div class="col-sm-9 product-description">
                                                            <div class="overflow-h">

                                                                <ul class="list-inline add-to-wishlist pull-right">
                                                                    <li>
                                                                        <i class="flaticon-id3"></i>
                                                                        <b>Expert ID : </b>419601                                                                    </li>
                                                                </ul>

                                                                <ul class="list-inline add-to-wishlist ">
                                                                    <li>
                                                                        <h4 class="title-price">
                                                                            <i class="fa fa-user"></i>
                                                                            <strong>
                                                                                Dr                                                                                Apoorva Bhatt                                                                            </strong>
                                                                        </h4>
                                                                    </li>
                                                                    <li>
                                                                        <span class="title-price">
                                                                            <i class="fa fa-briefcase"></i>
                                                                            Assistant Professor                                                                        </span>
                                                                    </li>
                                                                </ul>

                                                                <ul class="list-inline margin-bottom-5">
                                                                    <li>
                                                                        <i class="flaticon-light96"></i>
                                                                        <b>Astronomy and Astrophysics</b>
                                                                    </li>
                                                                </ul>
                                                                                                                                    <ul class="list-inline add-to-wishlist margin-bottom-5">
                                                                        <li>
                                                                            <i class="fa fa-cog"></i>
                                                                            Expertise is in detectors for particle physics, astronomy, nuclear physics and astrophysics.                                                                        </li>
                                                                    </ul>
                                                                                                
                                                                <ul class="list-inline add-to-wishlist">
                                                                    <li>
                                                                        <i class="glyphicon glyphicon-object-align-bottom"></i>
                                                                        Pandit Deendayal Energy University                                                                    </li>
                                                                    <li>
                                                                        <i class="fa fa-home"></i>
                                                                        Gujarat                                                                    </li>
                                                                </ul>

                                                                <a href="https://vidwan.inflibnet.ac.in/profile/419601" style="color: #FFF;" type="button"target="_blank" class="btn-u btn-u-dark-blue pull-right">View Profile</a>


                                                            </div>    
                                                        </div>
                                                        <!--/End  Display A Info-->
                                                    </div>
                                                </div>
                                            </div>  
                                            <!--/End Display A Result-->
                                            
                                            <!--Start  Display A Result-->
                                            <div class="list-product-description product-description-brd">
                                                <div class="row">
                                                    <div class="col-sm-12 ">

                                                        <!--Start  Display A Image-->
                                                        <div class="col-sm-3 product-description">
                                                                                                                        <a href="https://vidwan.inflibnet.ac.in/profile/420015" >
                                                                                                                                <img class="img-circle center-block img-responsive" src="http://irins.org/assets/profile_images/420015.jpg" />
                                                            </a>
                                                        </div>
                                                        <!--/End  Display A Image-->
                                                        <!--Start  Display A Info-->
                                                        <div class="col-sm-9 product-description">
                                                            <div class="overflow-h">

                                                                <ul class="list-inline add-to-wishlist pull-right">
                                                                    <li>
                                                                        <i class="flaticon-id3"></i>
                                                                        <b>Expert ID : </b>420015                                                                    </li>
                                                                </ul>

                                                                <ul class="list-inline add-to-wishlist ">
                                                                    <li>
                                                                        <h4 class="title-price">
                                                                            <i class="fa fa-user"></i>
                                                                            <strong>
                                                                                Dr                                                                                Nilesh Chothani                                                                            </strong>
                                                                        </h4>
                                                                    </li>
                                                                    <li>
                                                                        <span class="title-price">
                                                                            <i class="fa fa-briefcase"></i>
                                                                            Assistant Professor (Grade-III)                                                                        </span>
                                                                    </li>
                                                                </ul>

                                                                <ul class="list-inline margin-bottom-5">
                                                                    <li>
                                                                        <i class="flaticon-light96"></i>
                                                                        <b>Electrical and Electronic Engineering</b>
                                                                    </li>
                                                                </ul>
                                                                                                                                    <ul class="list-inline add-to-wishlist margin-bottom-5">
                                                                        <li>
                                                                            <i class="fa fa-cog"></i>
                                                                            Electrical Power System, Power system Protection and Switchgear, Smart Grid                                                                        </li>
                                                                    </ul>
                                                                                                
                                                                <ul class="list-inline add-to-wishlist">
                                                                    <li>
                                                                        <i class="glyphicon glyphicon-object-align-bottom"></i>
                                                                        Pandit Deendayal Energy University                                                                    </li>
                                                                    <li>
                                                                        <i class="fa fa-home"></i>
                                                                        Gujarat                                                                    </li>
                                                                </ul>

                                                                <a href="https://vidwan.inflibnet.ac.in/profile/420015" style="color: #FFF;" type="button"target="_blank" class="btn-u btn-u-dark-blue pull-right">View Profile</a>


                                                            </div>    
                                                        </div>
                                                        <!--/End  Display A Info-->
                                                    </div>
                                                </div>
                                            </div>  
                                            <!--/End Display A Result-->
                                            
                                            <!--Start  Display A Result-->
                                            <div class="list-product-description product-description-brd">
                                                <div class="row">
                                                    <div class="col-sm-12 ">

                                                        <!--Start  Display A Image-->
                                                        <div class="col-sm-3 product-description">
                                                                                                                        <a href="https://vidwan.inflibnet.ac.in/profile/420038" >
                                                                                                                                <img class="img-circle center-block img-responsive" src="http://irins.org/assets/profile_images/420038.jpeg" />
                                                            </a>
                                                        </div>
                                                        <!--/End  Display A Image-->
                                                        <!--Start  Display A Info-->
                                                        <div class="col-sm-9 product-description">
                                                            <div class="overflow-h">

                                                                <ul class="list-inline add-to-wishlist pull-right">
                                                                    <li>
                                                                        <i class="flaticon-id3"></i>
                                                                        <b>Expert ID : </b>420038                                                                    </li>
                                                                </ul>

                                                                <ul class="list-inline add-to-wishlist ">
                                                                    <li>
                                                                        <h4 class="title-price">
                                                                            <i class="fa fa-user"></i>
                                                                            <strong>
                                                                                Dr                                                                                Satyam Shinde                                                                            </strong>
                                                                        </h4>
                                                                    </li>
                                                                    <li>
                                                                        <span class="title-price">
                                                                            <i class="fa fa-briefcase"></i>
                                                                            Associate Professor                                                                        </span>
                                                                    </li>
                                                                </ul>

                                                                <ul class="list-inline margin-bottom-5">
                                                                    <li>
                                                                        <i class="flaticon-light96"></i>
                                                                        <b>Condensed Matter Physics</b>
                                                                    </li>
                                                                </ul>
                                                                                                                                    <ul class="list-inline add-to-wishlist margin-bottom-5">
                                                                        <li>
                                                                            <i class="fa fa-cog"></i>
                                                                            Computational Material Science
Density Functional theory, Perovskite solar cell, theroelectric materials, drug delivery                                                                        </li>
                                                                    </ul>
                                                                                                
                                                                <ul class="list-inline add-to-wishlist">
                                                                    <li>
                                                                        <i class="glyphicon glyphicon-object-align-bottom"></i>
                                                                        Pandit Deendayal Energy University                                                                    </li>
                                                                    <li>
                                                                        <i class="fa fa-home"></i>
                                                                        Gujarat                                                                    </li>
                                                                </ul>

                                                                <a href="https://vidwan.inflibnet.ac.in/profile/420038" style="color: #FFF;" type="button"target="_blank" class="btn-u btn-u-dark-blue pull-right">View Profile</a>


                                                            </div>    
                                                        </div>
                                                        <!--/End  Display A Info-->
                                                    </div>
                                                </div>
                                            </div>  
                                            <!--/End Display A Result-->
                                            
                                            <!--Start  Display A Result-->
                                            <div class="list-product-description product-description-brd">
                                                <div class="row">
                                                    <div class="col-sm-12 ">

                                                        <!--Start  Display A Image-->
                                                        <div class="col-sm-3 product-description">
                                                                                                                        <a href="https://vidwan.inflibnet.ac.in/profile/427689" >
                                                                                                                                <img class="img-circle center-block img-responsive" src="http://irins.org/assets/profile_images/427689.jpg" />
                                                            </a>
                                                        </div>
                                                        <!--/End  Display A Image-->
                                                        <!--Start  Display A Info-->
                                                        <div class="col-sm-9 product-description">
                                                            <div class="overflow-h">

                                                                <ul class="list-inline add-to-wishlist pull-right">
                                                                    <li>
                                                                        <i class="flaticon-id3"></i>
                                                                        <b>Expert ID : </b>427689                                                                    </li>
                                                                </ul>

                                                                <ul class="list-inline add-to-wishlist ">
                                                                    <li>
                                                                        <h4 class="title-price">
                                                                            <i class="fa fa-user"></i>
                                                                            <strong>
                                                                                Dr                                                                                PRAHLAD KUMAR BARUAH                                                                            </strong>
                                                                        </h4>
                                                                    </li>
                                                                    <li>
                                                                        <span class="title-price">
                                                                            <i class="fa fa-briefcase"></i>
                                                                            Assistant Professor (Grade-I)                                                                        </span>
                                                                    </li>
                                                                </ul>

                                                                <ul class="list-inline margin-bottom-5">
                                                                    <li>
                                                                        <i class="flaticon-light96"></i>
                                                                        <b>Optics</b>
                                                                    </li>
                                                                </ul>
                                                                                                                                    <ul class="list-inline add-to-wishlist margin-bottom-5">
                                                                        <li>
                                                                            <i class="fa fa-cog"></i>
                                                                            Prahlad K Baruah is currently working as an Assistant Professor in the Department of Physics, School of Technology, Pandit Deendayal Energy University, Gandhinagar, India. He has completed his Ph.D. from the Department of Physics, Indian Institute of Technology, Guwahati in 2019. 
Research Areas: Laser-matter interaction, Pulsed laser ablation in liquid, Nanoparticle synthesis, Laser micro-machining, Cavitation bubbles and Shock waves, Plasmonics, Antibacterial applications of metallic nanoparti                                                                        </li>
                                                                    </ul>
                                                                                                
                                                                <ul class="list-inline add-to-wishlist">
                                                                    <li>
                                                                        <i class="glyphicon glyphicon-object-align-bottom"></i>
                                                                        Pandit Deendayal Energy University                                                                    </li>
                                                                    <li>
                                                                        <i class="fa fa-home"></i>
                                                                        Gujarat                                                                    </li>
                                                                </ul>

                                                                <a href="https://vidwan.inflibnet.ac.in/profile/427689" style="color: #FFF;" type="button"target="_blank" class="btn-u btn-u-dark-blue pull-right">View Profile</a>


                                                            </div>    
                                                        </div>
                                                        <!--/End  Display A Info-->
                                                    </div>
                                                </div>
                                            </div>  
                                            <!--/End Display A Result-->
                                            
                                            <!--Start  Display A Result-->
                                            <div class="list-product-description product-description-brd">
                                                <div class="row">
                                                    <div class="col-sm-12 ">

                                                        <!--Start  Display A Image-->
                                                        <div class="col-sm-3 product-description">
                                                                                                                        <a href="https://vidwan.inflibnet.ac.in/profile/436936" >
                                                                                                                                <img class="img-circle center-block img-responsive" src="http://irins.org/assets/profile_images/men.png" />
                                                            </a>
                                                        </div>
                                                        <!--/End  Display A Image-->
                                                        <!--Start  Display A Info-->
                                                        <div class="col-sm-9 product-description">
                                                            <div class="overflow-h">

                                                                <ul class="list-inline add-to-wishlist pull-right">
                                                                    <li>
                                                                        <i class="flaticon-id3"></i>
                                                                        <b>Expert ID : </b>436936                                                                    </li>
                                                                </ul>

                                                                <ul class="list-inline add-to-wishlist ">
                                                                    <li>
                                                                        <h4 class="title-price">
                                                                            <i class="fa fa-user"></i>
                                                                            <strong>
                                                                                Dr                                                                                Bhinalkumar Mehta                                                                            </strong>
                                                                        </h4>
                                                                    </li>
                                                                    <li>
                                                                        <span class="title-price">
                                                                            <i class="fa fa-briefcase"></i>
                                                                            Assistant Professor (Grade-I)                                                                        </span>
                                                                    </li>
                                                                </ul>

                                                                <ul class="list-inline margin-bottom-5">
                                                                    <li>
                                                                        <i class="flaticon-light96"></i>
                                                                        <b>Electrical and Electronic Engineering</b>
                                                                    </li>
                                                                </ul>
                                                                                                                                    <ul class="list-inline add-to-wishlist margin-bottom-5">
                                                                        <li>
                                                                            <i class="fa fa-cog"></i>
                                                                            Electrical Machines, Power System, Renewable Energy- Solar and Wind                                                                        </li>
                                                                    </ul>
                                                                                                
                                                                <ul class="list-inline add-to-wishlist">
                                                                    <li>
                                                                        <i class="glyphicon glyphicon-object-align-bottom"></i>
                                                                        Pandit Deendayal Energy University                                                                    </li>
                                                                    <li>
                                                                        <i class="fa fa-home"></i>
                                                                        Gujarat                                                                    </li>
                                                                </ul>

                                                                <a href="https://vidwan.inflibnet.ac.in/profile/436936" style="color: #FFF;" type="button"target="_blank" class="btn-u btn-u-dark-blue pull-right">View Profile</a>


                                                            </div>    
                                                        </div>
                                                        <!--/End  Display A Info-->
                                                    </div>
                                                </div>
                                            </div>  
                                            <!--/End Display A Result-->
                                            
                                            <!--Start  Display A Result-->
                                            <div class="list-product-description product-description-brd">
                                                <div class="row">
                                                    <div class="col-sm-12 ">

                                                        <!--Start  Display A Image-->
                                                        <div class="col-sm-3 product-description">
                                                                                                                        <a href="https://vidwan.inflibnet.ac.in/profile/436956" >
                                                                                                                                <img class="img-circle center-block img-responsive" src="http://irins.org/assets/profile_images/men.png" />
                                                            </a>
                                                        </div>
                                                        <!--/End  Display A Image-->
                                                        <!--Start  Display A Info-->
                                                        <div class="col-sm-9 product-description">
                                                            <div class="overflow-h">

                                                                <ul class="list-inline add-to-wishlist pull-right">
                                                                    <li>
                                                                        <i class="flaticon-id3"></i>
                                                                        <b>Expert ID : </b>436956                                                                    </li>
                                                                </ul>

                                                                <ul class="list-inline add-to-wishlist ">
                                                                    <li>
                                                                        <h4 class="title-price">
                                                                            <i class="fa fa-user"></i>
                                                                            <strong>
                                                                                Dr                                                                                Kamal Kishore Garg                                                                            </strong>
                                                                        </h4>
                                                                    </li>
                                                                    <li>
                                                                        <span class="title-price">
                                                                            <i class="fa fa-briefcase"></i>
                                                                            Faculty                                                                        </span>
                                                                    </li>
                                                                </ul>

                                                                <ul class="list-inline margin-bottom-5">
                                                                    <li>
                                                                        <i class="flaticon-light96"></i>
                                                                        <b>Electrical and Electronic Engineering</b>
                                                                    </li>
                                                                </ul>
                                                                                                                                    <ul class="list-inline add-to-wishlist margin-bottom-5">
                                                                        <li>
                                                                            <i class="fa fa-cog"></i>
                                                                            Signal Processing and Wireless Communication                                                                        </li>
                                                                    </ul>
                                                                                                
                                                                <ul class="list-inline add-to-wishlist">
                                                                    <li>
                                                                        <i class="glyphicon glyphicon-object-align-bottom"></i>
                                                                        Pandit Deendayal Energy University                                                                    </li>
                                                                    <li>
                                                                        <i class="fa fa-home"></i>
                                                                        Gujarat                                                                    </li>
                                                                </ul>

                                                                <a href="https://vidwan.inflibnet.ac.in/profile/436956" style="color: #FFF;" type="button"target="_blank" class="btn-u btn-u-dark-blue pull-right">View Profile</a>


                                                            </div>    
                                                        </div>
                                                        <!--/End  Display A Info-->
                                                    </div>
                                                </div>
                                            </div>  
                                            <!--/End Display A Result-->
                                            
                                            <!--Start  Display A Result-->
                                            <div class="list-product-description product-description-brd">
                                                <div class="row">
                                                    <div class="col-sm-12 ">

                                                        <!--Start  Display A Image-->
                                                        <div class="col-sm-3 product-description">
                                                                                                                        <a href="https://vidwan.inflibnet.ac.in/profile/437015" >
                                                                                                                                <img class="img-circle center-block img-responsive" src="http://irins.org/assets/profile_images/437015.jpg" />
                                                            </a>
                                                        </div>
                                                        <!--/End  Display A Image-->
                                                        <!--Start  Display A Info-->
                                                        <div class="col-sm-9 product-description">
                                                            <div class="overflow-h">

                                                                <ul class="list-inline add-to-wishlist pull-right">
                                                                    <li>
                                                                        <i class="flaticon-id3"></i>
                                                                        <b>Expert ID : </b>437015                                                                    </li>
                                                                </ul>

                                                                <ul class="list-inline add-to-wishlist ">
                                                                    <li>
                                                                        <h4 class="title-price">
                                                                            <i class="fa fa-user"></i>
                                                                            <strong>
                                                                                Dr                                                                                Abhishek Gor                                                                            </strong>
                                                                        </h4>
                                                                    </li>
                                                                    <li>
                                                                        <span class="title-price">
                                                                            <i class="fa fa-briefcase"></i>
                                                                            Assistant Professor                                                                        </span>
                                                                    </li>
                                                                </ul>

                                                                <ul class="list-inline margin-bottom-5">
                                                                    <li>
                                                                        <i class="flaticon-light96"></i>
                                                                        <b>Applied Physics</b>
                                                                    </li>
                                                                </ul>
                                                                                                                                    <ul class="list-inline add-to-wishlist margin-bottom-5">
                                                                        <li>
                                                                            <i class="fa fa-cog"></i>
                                                                            Magnetic Materials and Device Physics                                                                        </li>
                                                                    </ul>
                                                                                                
                                                                <ul class="list-inline add-to-wishlist">
                                                                    <li>
                                                                        <i class="glyphicon glyphicon-object-align-bottom"></i>
                                                                        Pandit Deendayal Energy University                                                                    </li>
                                                                    <li>
                                                                        <i class="fa fa-home"></i>
                                                                        Gujarat                                                                    </li>
                                                                </ul>

                                                                <a href="https://vidwan.inflibnet.ac.in/profile/437015" style="color: #FFF;" type="button"target="_blank" class="btn-u btn-u-dark-blue pull-right">View Profile</a>


                                                            </div>    
                                                        </div>
                                                        <!--/End  Display A Info-->
                                                    </div>
                                                </div>
                                            </div>  
                                            <!--/End Display A Result-->
                                            
                                            <!--Start  Display A Result-->
                                            <div class="list-product-description product-description-brd">
                                                <div class="row">
                                                    <div class="col-sm-12 ">

                                                        <!--Start  Display A Image-->
                                                        <div class="col-sm-3 product-description">
                                                                                                                        <a href="https://vidwan.inflibnet.ac.in/profile/437552" >
                                                                                                                                <img class="img-circle center-block img-responsive" src="http://irins.org/assets/profile_images/437552.jpg" />
                                                            </a>
                                                        </div>
                                                        <!--/End  Display A Image-->
                                                        <!--Start  Display A Info-->
                                                        <div class="col-sm-9 product-description">
                                                            <div class="overflow-h">

                                                                <ul class="list-inline add-to-wishlist pull-right">
                                                                    <li>
                                                                        <i class="flaticon-id3"></i>
                                                                        <b>Expert ID : </b>437552                                                                    </li>
                                                                </ul>

                                                                <ul class="list-inline add-to-wishlist ">
                                                                    <li>
                                                                        <h4 class="title-price">
                                                                            <i class="fa fa-user"></i>
                                                                            <strong>
                                                                                Dr                                                                                Pavan Kumar Gurrala                                                                            </strong>
                                                                        </h4>
                                                                    </li>
                                                                    <li>
                                                                        <span class="title-price">
                                                                            <i class="fa fa-briefcase"></i>
                                                                            Associate Professor                                                                        </span>
                                                                    </li>
                                                                </ul>

                                                                <ul class="list-inline margin-bottom-5">
                                                                    <li>
                                                                        <i class="flaticon-light96"></i>
                                                                        <b>Mechanical Engineering</b>
                                                                    </li>
                                                                </ul>
                                                                                                                                    <ul class="list-inline add-to-wishlist margin-bottom-5">
                                                                        <li>
                                                                            <i class="fa fa-cog"></i>
                                                                            Dr. Pavan Kumar G has completed his B.Tech in Mechanical Engineering. He has done his ME in Design Engineering and PhD in Additive Manufacturing from BITS Pilani. He works in the area of polymer-based extrusion technologies. His areas of interest are the Design and Manufacturing of Bio-Implants, Medical aids for the needy in collaboration with prominent Orthopedic Surgeons and Dentists.                                                                        </li>
                                                                    </ul>
                                                                                                
                                                                <ul class="list-inline add-to-wishlist">
                                                                    <li>
                                                                        <i class="glyphicon glyphicon-object-align-bottom"></i>
                                                                        Pandit Deendayal Energy University                                                                    </li>
                                                                    <li>
                                                                        <i class="fa fa-home"></i>
                                                                        Gujarat                                                                    </li>
                                                                </ul>

                                                                <a href="https://vidwan.inflibnet.ac.in/profile/437552" style="color: #FFF;" type="button"target="_blank" class="btn-u btn-u-dark-blue pull-right">View Profile</a>


                                                            </div>    
                                                        </div>
                                                        <!--/End  Display A Info-->
                                                    </div>
                                                </div>
                                            </div>  
                                            <!--/End Display A Result-->
                                            
                                            <!--Start  Display A Result-->
                                            <div class="list-product-description product-description-brd">
                                                <div class="row">
                                                    <div class="col-sm-12 ">

                                                        <!--Start  Display A Image-->
                                                        <div class="col-sm-3 product-description">
                                                                                                                        <a href="https://vidwan.inflibnet.ac.in/profile/466436" >
                                                                                                                                <img class="img-circle center-block img-responsive" src="http://irins.org/assets/profile_images/4664363.JPG" />
                                                            </a>
                                                        </div>
                                                        <!--/End  Display A Image-->
                                                        <!--Start  Display A Info-->
                                                        <div class="col-sm-9 product-description">
                                                            <div class="overflow-h">

                                                                <ul class="list-inline add-to-wishlist pull-right">
                                                                    <li>
                                                                        <i class="flaticon-id3"></i>
                                                                        <b>Expert ID : </b>466436                                                                    </li>
                                                                </ul>

                                                                <ul class="list-inline add-to-wishlist ">
                                                                    <li>
                                                                        <h4 class="title-price">
                                                                            <i class="fa fa-user"></i>
                                                                            <strong>
                                                                                Mr                                                                                Gaurav Hazarika                                                                            </strong>
                                                                        </h4>
                                                                    </li>
                                                                    <li>
                                                                        <span class="title-price">
                                                                            <i class="fa fa-briefcase"></i>
                                                                            Assistant Professor                                                                        </span>
                                                                    </li>
                                                                </ul>

                                                                <ul class="list-inline margin-bottom-5">
                                                                    <li>
                                                                        <i class="flaticon-light96"></i>
                                                                        <b>Petroleum Engineering</b>
                                                                    </li>
                                                                </ul>
                                                                                                                                    <ul class="list-inline add-to-wishlist margin-bottom-5">
                                                                        <li>
                                                                            <i class="fa fa-cog"></i>
                                                                            EOR, Field Development, Matrix Acidization, Cementing and Drilling                                                                        </li>
                                                                    </ul>
                                                                                                
                                                                <ul class="list-inline add-to-wishlist">
                                                                    <li>
                                                                        <i class="glyphicon glyphicon-object-align-bottom"></i>
                                                                        Pandit Deendayal Energy University                                                                    </li>
                                                                    <li>
                                                                        <i class="fa fa-home"></i>
                                                                        Gujarat                                                                    </li>
                                                                </ul>

                                                                <a href="https://vidwan.inflibnet.ac.in/profile/466436" style="color: #FFF;" type="button"target="_blank" class="btn-u btn-u-dark-blue pull-right">View Profile</a>


                                                            </div>    
                                                        </div>
                                                        <!--/End  Display A Info-->
                                                    </div>
                                                </div>
                                            </div>  
                                            <!--/End Display A Result-->
                                                                                    
                                        <!--Start Pagination bottom-->    
                                        <div class="text-center">
                                            <ul class="pagination">
                                                                                            </ul>
                                        </div>
                                        <!--/End Pagination bottom-->
                                        <!--/End else section-->
                                </div>
                            </div>
                            <!--/End Result Display-->
                        </div>
                        <!--/end row--> 

                        <input type="hidden" name="cPageNo" id="cPageNo"/>
                    </form>
                    <!--/End Form ===-->
                </div>
                <!--=== /End Search Page ===-->    
                <!--=== Footer ===-->
                <!-- CSS Custom to Override-->
<link href="https://vidwan.inflibnet.ac.in/files/assets/plugins/image-hover/css/img-hover.css" rel="stylesheet" />  

<!-- CSS Custom to Override-->
<link href="https://vidwan.inflibnet.ac.in/files/datatable/myfooter.css" rel="stylesheet" />  
<!--=== Job Partners ===-->

<ul class="list-inline our-clients" id="effect-2">
    <li>
        <figure>
            <a href="http://indcat.inflibnet.ac.in/">
                <img src="https://vidwan.inflibnet.ac.in/files/myicons/projects/Indcat.png" alt="">
                <div class="img-hover">
                    <h4>INDCAT</h4>
                
                </div>
            </a>
        </figure>
    </li>
    <li>
        <figure>
            <a href="https://soul.inflibnet.ac.in/">
                <img src="https://vidwan.inflibnet.ac.in/files/myicons/projects/2.png" alt="">
                <div class="img-hover">
                    <h4>SOUL</h4>
                </div>
            </a>
        </figure>
    </li>
    <li>
        <figure>
            <a href="http://shodhganga.inflibnet.ac.in/">
                <img src="https://vidwan.inflibnet.ac.in/files/myicons/projects/3.png" alt="">
                <div class="img-hover">
                    <h4>SHODH GANGA</h4>
                </div>
            </a>
        </figure>
    </li>
    <li>
        <figure>
            <a href="http://content.inflibnet.ac.in/">
                <img src="https://vidwan.inflibnet.ac.in/files/myicons/projects/Vidyamitra.png" alt="">
                <div class="img-hover">
                    <h4>VIDYA-MITRA</h4>
                </div>
            </a>
        </figure>
    </li>
    <li>
        <figure>
            <a href="https://ess.inflibnet.ac.in/">
                <img src="https://vidwan.inflibnet.ac.in/files/myicons/projects/5.png" alt="">
                <div class="img-hover">
                    <h4>e-SHODH SINDHU</h4>
                </div>
            </a>
        </figure>
    </li>
    <li>
        <figure>
            <a href="http://infoport.inflibnet.ac.in/">
                <img src="https://vidwan.inflibnet.ac.in/files/myicons/projects/6.png" alt="">
                <div class="img-hover">
                    <h4>INFOPORTAL</h4>
                </div>
            </a>
        </figure>
    </li>
    <li>
        <figure>
            <a href="http://epgp.inflibnet.ac.in">
                <img src="https://vidwan.inflibnet.ac.in/files/myicons/projects/7.png" alt="">
                <div class="img-hover">
                    <h4>e-PG PATHSHALA</h4>
                </div>
            </a>
        </figure>
    </li>
    <br>
    <li>
        <figure>
            <a href="http://ir.inflibnet.ac.in/">
                <img src="https://vidwan.inflibnet.ac.in/files/myicons/projects/9.png" alt="">
                <div class="img-hover">
                    <h4>Institutional Repository</h4>
                </div>
            </a>
        </figure>
    </li>
    <li>
        <figure>
            <a href="https://parichay.inflibnet.ac.in/">
                <img src="https://vidwan.inflibnet.ac.in/files/myicons/projects/10.png" alt="">
                <div class="img-hover">
                    <h4>INFED</h4>
                </div>
            </a>
        </figure>
    </li>
    <li>
        <figure>
            <a href="https://shodhshuddhi.inflibnet.ac.in/">
                <img src="https://vidwan.inflibnet.ac.in/files/myicons/projects/11.png" alt="">
                <div class="img-hover">
                    <h4>Shodh Shuddhi</h4>
                </div>
            </a>
        </figure>
    </li>
    <li>
        <figure>
            <a href="https://nlist.inflibnet.ac.in/">
                <img src="https://vidwan.inflibnet.ac.in/files/myicons/projects/12.png" alt="">
                <div class="img-hover">
                    <h4>N-LIST</h4>
                </div>
            </a>
        </figure>
    </li>
    <li>
        <figure>
            <a href="https://infistat.inflibnet.ac.in/">
                <img src="https://vidwan.inflibnet.ac.in/files/myicons/projects/13.png" alt="">
                <div class="img-hover">
                    <h4>INFISTATS</h4>
                </div>
            </a>
        </figure>
    </li>
    
    <li>
        <figure>
            <a href="https://irins.org/irins/">
                <img src="https://vidwan.inflibnet.ac.in/files/myicons/projects/IRINS.png" alt="">
                <div class="img-hover">
                    <h4>IRINS</h4>
                </div>
            </a>
        </figure>
    </li>
    <li>
        <figure>
            <a href="https://www.nirfindia.org/Home">
                <img src="https://vidwan.inflibnet.ac.in/files/myicons/projects/NIRF.png" alt="">
                <div class="img-hover">
                    <h4>NIRF</h4>
                </div>
            </a>
        </figure>
    </li>
</ul>
<!--=== End Job Partners ===-->        

<!--=== Footer Version 1 ===-->
<div class="footer-v1">

    <div class="footer" >
        <div class="container">

            <div class="row" style="margin-right: -15px; margin-left: -15px;">
                <!-- About -->
                <div class="col-md-3 md-margin-bottom-40">
                    <a href="http://www.nmeict.ac.in" target="_blank"><img id="logo-footer" class="footer-logo" src="https://vidwan.inflibnet.ac.in/files/myicons/projects/img (13).png" alt="NME-ICT Logo" style="width:175px;margin: 15px 0px 5px 0px;"></a>
<!--                <a href="http://www.ugc.ac.in/" target="_blank"> <img id="logo-footer" class="footer-logo" src="https://vidwan.inflibnet.ac.in/files/myicons/projects/img (22).png" alt="UGC Logo" style="width:170px;margin: 0px 0px 0px -2px;"></a>-->
                    <a href="http://www.inflibnet.ac.in" target="_blank"><img id="logo-footer" class="footer-logo" src="https://vidwan.inflibnet.ac.in/files/myicons/projects/img (6).png" alt="INFLIBNET Logo" style="width:182px;margin: 0px 0px 0px 3px;"></a>
                    <hr style="width: 71%;">
                    <div><h2><a href = 'https://mhrd.gov.in/ict-initiatives' style="color: white;" target="blank">ICT Initiatives of MoE</a></h2></div><hr style="width: 71%;">
                </div><!--/col-md-3-->
                <!-- End About -->

                <!-- Latest -->
                <div class="col-md-9 ">
                    <div class="headline"><h2>Contact Us</h2></div>
                </div><!--/col-md-12-->


                <!-- End Latest --> 

                <!-- Link List -->
                <div class="col-md-3 md-margin-bottom-40">
                    <ul class="list-unstyled who margin-bottom-30" style="color: #F7F7F7;">
                        <li style="color: #eee;">
                            The Director<br/>
                            Information and Library Network Centre,<br/>
                            Infocity,Gandhinagar<br/>
                            Gujarat - 382007
                        </li>
						<li style="margin-top:8px;"><a href="https://vidwan.inflibnet.ac.in/disclaimer">Disclaimer</a></li>
                    </ul>
                </div><!--/col-md-3-->
                <!-- End Link List -->                    

                <!-- Address -->
                <div class="col-md-3 map-img md-margin-bottom-40">
                    <address class="md-margin-bottom-40">
                        <ul class="list-unstyled who latest-list margin-bottom-30">
                            <li style="color: #eee;" ><i class="fa fa-user"></i>Shri Kannan P</li>
                            <li style="color: #eee;" ><i class="fa fa-briefcase"></i>Scientist-E (LS)</li>
                            <li><a  href="mailto:vidwan@inflibnet.ac.in"><i class="fa fa-envelope"></i>vidwan@inflibnet.ac.in</a></li>
                        </ul>
                    </address>
                </div><!--/col-md-3-->

                <!-- End Address -->
                <div class="col-md-2 map-img md-margin-bottom-40">
                    <address class="md-margin-bottom-40">
                        <ul class="list-unstyled who latest-list margin-bottom-30">
                            <li style="color: #eee;" ><i class="fa fa-user"></i>Shri Yatrik Patel</li>
                            <li style="color: #eee;" ><i class="fa fa-briefcase"></i>Scientist-E (CS)</li>
                            <!--<li><a href="mailto:yatrik@inflibnet.ac.in"><i class="fa fa-envelope"></i>yatrik@inflibnet.ac.in</a></li> -->
                        </ul>
                    </address>
                </div><!--/col-md-3-->
                <!-- End Address -->
                <!-- Address -->
                <div class="col-md-3 map-img md-margin-bottom-40">
                    <address class="md-margin-bottom-40">
                        <ul class="list-unstyled who latest-list margin-bottom-30">
                            <li style="color: #eee;" ><i class="fa fa-user"></i>Shri Abhishek Kumar</li>
                            <li style="color: #eee;" ><i class="fa fa-briefcase"></i>Scientist-E (CS)</li>
                            <!--<li><a href="mailto:abhishek@inflibnet.ac.in"><i class="fa fa-envelope"></i>abhishek@inflibnet.ac.in</a></li> -->
                        </ul>
                    </address>
                </div><!--/col-md-3-->
                <!-- End Address -->
            </div>
        </div> 
    </div><!--/footer-->

    <div class="copyright">
        <div class="container">
            <div class="row">
            </div>
        </div> 
    </div><!--/copyright-->
</div>     
<!--=== End Footer Version 1 ===-->                <!--=== End Footer===-->
            </div>
            <!--/End wrapper-->
        </div>
        <div id="loading"></div>
    </body>
    <script type="text/javascript">

    </script>
    <script type="text/javascript" src="https://vidwan.inflibnet.ac.in/files/assets/plugins/image-hover/js/touch.js"></script>
    <script type="text/javascript" src="https://vidwan.inflibnet.ac.in/files/assets/plugins/image-hover/js/modernizr.js"></script>
    <script>
        function onReady(callback) {
            var intervalID = window.setInterval(checkReady, 500);

            function checkReady() {
                if (document.getElementsByTagName('body')[0] !== undefined) {
                    window.clearInterval(intervalID);
                    callback.call(this);
                }
            }
        }

        function show(id, value) {
            document.getElementById(id).style.display = value ? 'block' : 'none';
        }

        onReady(function () {
            show('page', true);
            show('loading', false);
        });
    </script>
    <script>
        $(function () {
            $(".links").on("click", function (event) {
                event.preventDefault();
                var pageNo = $(this).attr('href');
                $("#cPageNo").val(pageNo);
                $("#myform").submit();
            });
        });
    </script>

    <script>

        $(function () {
            $('#limits').change(function (event) {
                event.preventDefault();
                var limits = $(this).val();
               // alert("In Submit" + limits);
                $("#limits").val(limits);
                $("#myform").submit();
            });
        });

        //On load of view(page) gets limit value passed from controller and make it selected in Select Input
        $(function () {
            var limits = 100;
            //        alert("From Controller: " + limits);
            $("#limits").val(limits);
        });

    </script>

    <script>

        $(function () {
            $('#sortfield').change(function (event) {
                event.preventDefault();
                var sortf = $(this).val();
                //          alert("In Submit " + sortf);
                $("#sortfield").val(sortf);
                $("#myform").submit();
            });
        });

        //On load of view(page) gets sorts value passed from controller and make it selected in Select Input

        $(function () {
            var sorted = 'user_id';
            //      alert("From Controller: " +sorted);
            $("#sortfield").val(sorted);
        });

    </script>
    <script>
        $(function () {
            $("#search").click(function () {
                $("#myform").validate({
                    rules: {
                        title: {
                            required: true,
                            minlength: 1,
                            maxlength: 200
                        }
                    },
                    messages: {
                        title: {
                            required: "Please Enter some characters to search."
                        }
                    },
                    submitHandler: function (form) {
                        $(form).ajaxSubmit();
                    },
                    errorPlacement: function (error, element)
                    {
                        error.insertBefore($("#errornous"));
                    }
                });
            });
        });

    </script>
    <script>
//        $(function () {
//            $('input[type="radio"]').click(function () {
//                if ($(this).is(':checked'))
//                {
//                    var option = $(this).val();
//                    alert("Please Enter Some text to search " + option);
//
//                }
//            });
//        });

        //    $(function () {
        //        var option = exact;
        //        alert("From Controller: " + option);
        //       $("#exact").prop("checked", true)
        //    });
    </script>
    <script>
        $(function () {
            $("#search").click(function () {
                //alert("click");
                $("input[name='org_type[]']").prop('checked', false);
                $("input[name='organisation[]']").prop('checked', false);
                $("input[name='designation[]']").prop('checked', false);
                $("input[name='expertise[]']").prop('checked', false);
                $("input[name='state[]']").prop('checked', false);
                $("input[name='wos_sub[]']").prop('checked', false);
                //Then submit form
                $("#myform").submit();
            });
        });
    </script>
    <script>
        jQuery(document).ready(function () {

            //LoginForm.initLoginForm();
            $("#error").hide();
            $("#login").click(function () {
                var username = $("#username").val();
                var password = $("#password").val();

                if (username == "")
                {
                    window.location = "https://vidwan.inflibnet.ac.in/login";
                }
                else if (password == "") {
                    window.location = "https://vidwan.inflibnet.ac.in/login";
                }
                else {
                    $.ajax({
                        type: "post",
                        url: "https://vidwan.inflibnet.ac.in/login/verifyUser",
                        cache: false,
                        data: $('#loginform').serialize(),
                        success: function (json) {
                            // alert(json);
                            try {
                                var obj = jQuery.parseJSON(json);
                                if (obj["status"] == "true") {
                                    window.location = "https://vidwan.inflibnet.ac.in/myprofile";
                                }
                                else {
                                    window.location = "https://vidwan.inflibnet.ac.in/login";
                                }
                            } catch (e) {
                                //alert('Exception while request..');
                            }
                        },
                        error: function () {
                            //alert('Error while request..');
                        }
                    });

                }
            });





        });
    </script>




</html>	
'''

# %%
soup = BeautifulSoup(content, 'html5lib') # If this line causes an error, run 'pip install html5lib' or install html5lib 
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <!--[if IE 8]> <html lang="en" class="ie8"> <![endif]-->
# <!--[if IE 9]> <html lang="en" class="ie9"> <![endif]-->
# <!--[if !IE]><!-->
# <html lang="en">
#  <!--<![endif]-->
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <link href="../../favicon.ico" rel="icon"/>
#   <title>
#    Vidwan Search Expert
#   </title>
#   <!-- Web Fonts -->
#   <link href="https://fonts.googleapis.com/css?family=Open+Sans:400,300,600&amp;subset=cyrillic,latin" rel="stylesheet" type="text/css"/>
#   <!-- CSS Global Compulsory -->
#   <link href="https://vidwan.inflibnet.ac.in/files/assets/plugins/bootstrap/css/bootstrap.min.css" rel="stylesheet"/>
#   <link href="https://vidwan.inflibnet.ac.in/files/assets/css/style.css" rel="stylesheet"/>
#   <!-- CSS Header and Footer -->
#   <link href="https://vidwan.inflibnet.ac.in/files/assets/css/headers/header-default.css" rel="stylesheet"/>
# ...

# %%
h4_elements = soup.find_all('h4', class_='title-price')

# Extract the text from the strong tag inside the h4 tag
names = [h4.strong.text.strip().replace("   ","") for h4 in h4_elements]
names
# Out:
# ['Dr  Bhawanisingh Desai',
#  'Dr  Santosh Satapathy',
#  'Dr  Ayyanna  Habal',
#  'Dr  Mohendra Roy',
#  'Dr  Ravi Tejasvi',
#  'Dr  Abhishek Kumar Gupta',
#  'Dr  Rohit Srivastava',
#  'Dr  Apoorva Bhatt',
#  'Dr  Nilesh Chothani',
#  'Dr  Satyam Shinde',
#  'Dr  PRAHLAD KUMAR BARUAH',
#  'Dr  Bhinalkumar Mehta',
#  'Dr  Kamal Kishore Garg',
#  'Dr  Abhishek Gor',
#  'Dr  Pavan Kumar Gurrala',
#  'Mr  Gaurav Hazarika']
